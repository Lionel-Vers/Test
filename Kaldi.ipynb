# %% [markdown]
# <a href="https://colab.research.google.com/github/Lionel-Vers/Test/blob/main/Kaldi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Bienvenue dans Colab !</h1>
# </div>
#
# Si vous connaissez déjà Colab, regardez cette vidéo pour découvrir les tables interactives, l'affichage de l'historique du code exécuté et la palette de commandes.
#
# <center>
#   <a href="https://www.youtube.com/watch?v=rNgswRZ2C1Y" target="_blank">
#   <img alt='Vignette d'une vidéo affichant trois fonctionnalités intéressantes de Google Colab' src="data:image/png;base64,..." height="188" width="336">
#   </a>
# </center>

# %%
# !ls -all
# Out:
# total 420984
# drwxr-xr-x  8 root  root      4096 Feb 19 18:03 .
# drwxr-xr-x  4 root  root      4096 Feb 19 17:51 ..
# -rw-r--r--  1 root  root 214046656 Feb 26  2022 0013_librispeech_v1_chain.tar.gz
# -rw-r--r--  1 root  root  19121926 Dec 27  2020 0013_librispeech_v1_extractor.tar.gz
# -rw-r--r--  1 root  root 197387188 Jan 17  2021 0013_librispeech_v1_lm.tar.gz
# -rw-r--r--  1 root  root       904 Feb 19 17:51 cmd.sh
# drwxr-xr-x  2 root  root      4096 Feb 19 17:51 conf
# drwxr-xr-x  5 61208 fax       4096 Jan 17  2021 data
# drwxr-xr-x  5 61208 fax       4096 Dec 27  2020 exp
# -rwxr-xr-x  1 root  root    441180 Feb 19 17:51 gettysburg.wav
# -rw-r--r--  1 root  root      5929 Feb 19 18:03 main_log.txt
# -rw-r--r--  1 root  root      5960 Feb 19 17:51 main.py
# -rwxr-xr-x  1 root  root      1072 Feb 19 17:51 path.sh
# drwxr-xr-x  2 root  root      4096 Feb 19 18:03 __pycache__
# -rw-r--r--  1 root  root       414 Feb 19 17:51 reset_directory_completely.py
# -rw-r--r--  1 root  root       283 Feb 19 17:51 reset_directory.py
# -rwxr-xr-x  1 root  root     12322 Feb 19 17:51 run.sh
# drwxr-xr-x 19 root  root      4096 Feb 19 17:51 steps
# drwxr-xr-x 11 root  root      4096 Feb 19 17:51 utils

# %%
# !find -type d -name egs
# Out:
# find: ‘./proc/64/task/64/net’: Invalid argument
# find: ‘./proc/64/net’: Invalid argument

# %%
# Out:
# --2023-02-19 13:58:12--  https://raw.githubusercontent.com/AssemblyAI/kaldi-asr-tup.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 400 Bad Request
# 2023-02-19 13:58:12 ERROR 400: Bad Request.

# %%
# !cd ..

# %%
# !ls
# Out:
# sample_data

# %%
cd sample_data/
# Out:
# /content/sample_data

# %%
# !ls -R ./
# Out:
# ./:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %%
# !ls
# Out:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %%
# !find . -name Google_Colab.txt

# %%
# !find -name Google_Colab.txt

# %%
# !cat Google_Colab.txt
# Out:
# cat: Google_Colab.txt: No such file or directory

# %%
# !cat Google_Colab
# Out:
# cat: Google_Colab: No such file or directory

# %%
# !find . -name Google_Colab.txt

# %%
# !git clone https://github.com/kaldi-asr/kaldi.git kaldi --origin upstream
# Out:
# Cloning into 'kaldi'...
# remote: Enumerating objects: 115154, done.
# remote: Counting objects: 100% (99/99), done.
# remote: Compressing objects: 100% (83/83), done.
# remote: Total 115154 (delta 33), reused 50 (delta 15), pack-reused 115055
# Receiving objects: 100% (115154/115154), 121.97 MiB | 32.69 MiB/s, done.
# Resolving deltas: 100% (88712/88712), done.

# %%
# !cd ./kaldi/tools

# %%
# !cd ./content/sample_data
# Out:
# /bin/bash: line 0: cd: ./content/sample_data: No such file or directory

# %%
# !cd ./kaldi/tools

# %%
# !ls
# Out:
# anscombe.json		      kaldi		     README.md
# california_housing_test.csv   mnist_test.csv
# california_housing_train.csv  mnist_train_small.csv

# %%
# !yes | extras/install_mkl.sh
# Out:
# /bin/bash: extras/install_mkl.sh: No such file or directory

# %%
# !cd kaldi

# %%
# !ls
# Out:
# anscombe.json		      kaldi		     README.md
# california_housing_test.csv   mnist_test.csv
# california_housing_train.csv  mnist_train_small.csv

# %%
# !cd kaldi/

# %%
# !ls
# Out:
# anscombe.json		      kaldi		     README.md
# california_housing_test.csv   mnist_test.csv
# california_housing_train.csv  mnist_train_small.csv

# %%
# !cd ./kaldi

# %%
# !ls
# Out:
# anscombe.json		      kaldi		     README.md
# california_housing_test.csv   mnist_test.csv
# california_housing_train.csv  mnist_train_small.csv

# %%
# !ls ./content/sample_data
# Out:
# ls: cannot access './content/sample_data': No such file or directory

# %%
# !ls ./kaldi/tools/
# Out:
# ATLAS_headers  extras		       install_portaudio.sh  Makefile
# CLAPACK        INSTALL		       install_speex.sh
# config	       install_pfile_utils.sh  install_srilm.sh

# %%
# !ls | cd ./kaldi/tools/extras

# %%
# !ls
# Out:
# anscombe.json		      kaldi		     README.md
# california_housing_test.csv   mnist_test.csv
# california_housing_train.csv  mnist_train_small.csv

# %%
# !yes | ./kaldi/tools/extras/install_mkl.sh
# Out:
# ./kaldi/tools/extras/install_mkl.sh: Your system is using debian-style package management.
# + apt-get update
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease [3,622 B]
# Get:2 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease [18.1 kB]
# Hit:3 http://archive.ubuntu.com/ubuntu focal InRelease
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu2004/x86_64  InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease
# Hit:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu2004/x86_64  Release
# Get:7 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Get:8 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Hit:9 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Hit:11 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease
# Get:12 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# Hit:13 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu focal InRelease
# Get:14 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [2,970 kB]
# Hit:15 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal InRelease
# Get:16 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal/main Sources [2,386 kB]
# Get:17 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal/main amd64 Packages [1,131 kB]
# Fetched 6,844 kB in 2s (3,091 kB/s)
# Reading package lists... Done
# + apt-get install -y wget apt-transport-https ca-certificates gnupg
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ca-certificates is already the newest version (20211016ubuntu0.20.04.1).
# gnupg is already the newest version (2.2.19-3ubuntu2.2).
# gnupg set to manually installed.
# wget is already the newest version (1.20.3-1ubuntu2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-510
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   apt-transport-https
# 0 upgraded, 1 newly installed, 0 to remove and 22 not upgraded.
# Need to get 1,704 B of archives.
# After this operation, 162 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 apt-transport-https all 2.0.9 [1,704 B]
# Fetched 1,704 B in 0s (48.0 kB/s)
# Selecting previously unselected package apt-transport-https.
# (Reading database ... 128126 files and directories currently installed.)
# Preparing to unpack .../apt-transport-https_2.0.9_all.deb ...
# Unpacking apt-transport-https (2.0.9) ...
# Setting up apt-transport-https (2.0.9) ...
# + wget -qO- https://apt.repos.intel.com/intel-gpg-keys/GPG-PUB-KEY-INTEL-SW-PRODUCTS-2019.PUB
# + apt-key --keyring /usr/share/keyrings/intel-sw-products.gpg add -
# OK
# + echo 'deb [signed-by=/usr/share/keyrings/intel-sw-products.gpg] https://apt.repos.intel.com/mkl all main'
# Hit:1 http://archive.ubuntu.com/ubuntu focal InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu focal-updates InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu focal-backports InRelease
# Get:5 https://apt.repos.intel.com/mkl all InRelease [4,438 B]
# Hit:6 http://security.ubuntu.com/ubuntu focal-security InRelease
# Hit:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease
# Ign:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu2004/x86_64  InRelease
# Hit:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease
# Hit:10 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu2004/x86_64  Release
# Hit:11 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Hit:12 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease
# Get:13 https://apt.repos.intel.com/mkl all/main all Packages [35.0 kB]
# Get:14 https://apt.repos.intel.com/mkl all/main amd64 Packages [140 kB]
# Hit:15 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu focal InRelease
# Hit:17 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal InRelease
# Fetched 179 kB in 1s (189 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-510
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   intel-comp-l-all-vars-19.1.0-166 intel-comp-nomcu-vars-19.1.0-166
#   intel-conda-index-tool-19.1.0-166
#   intel-conda-intel-openmp-linux-64-shadow-package-19.1.0-166
#   intel-conda-mkl-devel-linux-64-shadow-package-2020.0-166
#   intel-conda-mkl-include-linux-64-shadow-package-2020.0-166
#   intel-conda-mkl-linux-64-shadow-package-2020.0-166
#   intel-conda-mkl-static-linux-64-shadow-package-2020.0-166
#   intel-conda-tbb-linux-64-shadow-package-2020.0-166
#   intel-mkl-cluster-2020.0-166 intel-mkl-cluster-c-2020.0-166
#   intel-mkl-cluster-f-2020.0-166 intel-mkl-cluster-rt-2020.0-166
#   intel-mkl-common-2020.0-166 intel-mkl-common-c-2020.0-166
#   intel-mkl-common-c-ps-2020.0-166 intel-mkl-common-f-2020.0-166
#   intel-mkl-common-ps-2020.0-166 intel-mkl-core-2020.0-166
#   intel-mkl-core-c-2020.0-166 intel-mkl-core-f-2020.0-166
#   intel-mkl-core-ps-2020.0-166 intel-mkl-core-rt-2020.0-166 intel-mkl-doc-2020
#   intel-mkl-doc-ps-2020 intel-mkl-f95-2020.0-166
#   intel-mkl-f95-common-2020.0-166 intel-mkl-gnu-2020.0-166
#   intel-mkl-gnu-c-2020.0-166 intel-mkl-gnu-f-2020.0-166
#   intel-mkl-gnu-f-rt-2020.0-166 intel-mkl-gnu-rt-2020.0-166
#   intel-mkl-pgi-2020.0-166 intel-mkl-pgi-c-2020.0-166
#   intel-mkl-pgi-rt-2020.0-166 intel-mkl-psxe-2020.0-088
#   intel-mkl-tbb-2020.0-166 intel-mkl-tbb-rt-2020.0-166 intel-openmp-19.1.0-166
#   intel-psxe-common-2020.0-088 intel-psxe-common-doc-2020
#   intel-tbb-libs-2020.0-166
# The following NEW packages will be installed:
#   intel-comp-l-all-vars-19.1.0-166 intel-comp-nomcu-vars-19.1.0-166
#   intel-conda-index-tool-19.1.0-166
#   intel-conda-intel-openmp-linux-64-shadow-package-19.1.0-166
#   intel-conda-mkl-devel-linux-64-shadow-package-2020.0-166
#   intel-conda-mkl-include-linux-64-shadow-package-2020.0-166
#   intel-conda-mkl-linux-64-shadow-package-2020.0-166
#   intel-conda-mkl-static-linux-64-shadow-package-2020.0-166
#   intel-conda-tbb-linux-64-shadow-package-2020.0-166
#   intel-mkl-64bit-2020.0-088 intel-mkl-cluster-2020.0-166
#   intel-mkl-cluster-c-2020.0-166 intel-mkl-cluster-f-2020.0-166
#   intel-mkl-cluster-rt-2020.0-166 intel-mkl-common-2020.0-166
#   intel-mkl-common-c-2020.0-166 intel-mkl-common-c-ps-2020.0-166
#   intel-mkl-common-f-2020.0-166 intel-mkl-common-ps-2020.0-166
#   intel-mkl-core-2020.0-166 intel-mkl-core-c-2020.0-166
#   intel-mkl-core-f-2020.0-166 intel-mkl-core-ps-2020.0-166
#   intel-mkl-core-rt-2020.0-166 intel-mkl-doc-2020 intel-mkl-doc-ps-2020
#   intel-mkl-f95-2020.0-166 intel-mkl-f95-common-2020.0-166
#   intel-mkl-gnu-2020.0-166 intel-mkl-gnu-c-2020.0-166
#   intel-mkl-gnu-f-2020.0-166 intel-mkl-gnu-f-rt-2020.0-166
#   intel-mkl-gnu-rt-2020.0-166 intel-mkl-pgi-2020.0-166
#   intel-mkl-pgi-c-2020.0-166 intel-mkl-pgi-rt-2020.0-166
#   intel-mkl-psxe-2020.0-088 intel-mkl-tbb-2020.0-166
#   intel-mkl-tbb-rt-2020.0-166 intel-openmp-19.1.0-166
#   intel-psxe-common-2020.0-088 intel-psxe-common-doc-2020
#   intel-tbb-libs-2020.0-166
# 0 upgraded, 43 newly installed, 0 to remove and 22 not upgraded.
# Need to get 300 MB of archives.
# After this operation, 0 B of additional disk space will be used.
# Get:1 https://apt.repos.intel.com/mkl all/main amd64 intel-comp-l-all-vars-19.1.0-166 all 19.1.0-166 [9,348 B]
# Get:2 https://apt.repos.intel.com/mkl all/main amd64 intel-comp-nomcu-vars-19.1.0-166 all 19.1.0-166 [5,754 B]
# Get:3 https://apt.repos.intel.com/mkl all/main amd64 intel-conda-index-tool-19.1.0-166 amd64 19.1.0-166 [15.1 MB]
# Get:4 https://apt.repos.intel.com/mkl all/main amd64 intel-conda-intel-openmp-linux-64-shadow-package-19.1.0-166 amd64 19.1.0-166 [8,146 B]
# Get:5 https://apt.repos.intel.com/mkl all/main amd64 intel-tbb-libs-2020.0-166 amd64 2020.0-166 [645 kB]
# Get:6 https://apt.repos.intel.com/mkl all/main amd64 intel-conda-tbb-linux-64-shadow-package-2020.0-166 amd64 2020.0-166 [8,238 B]
# Get:7 https://apt.repos.intel.com/mkl all/main amd64 intel-openmp-19.1.0-166 amd64 19.1.0-166 [1,810 kB]
# Get:8 https://apt.repos.intel.com/mkl all/main amd64 intel-mkl-doc-2020 all 2020.4-304 [12.6 kB]
# Get:9 https://apt.repos.intel.com/mkl all/main amd64 intel-mkl-common-2020.0-166 all 2020.0-166 [93.0 kB]
# Get:10 https://apt.repos.intel.com/mkl all/main amd64 intel-mkl-core-rt-2020.0-166 amd64 2020.0-166 [126 MB]
# Get:11 https://apt.repos.intel.com/mkl all/main amd64 intel-mkl-core-2020.0-166 amd64 2020.0-166 [106 MB]
# Get:12 https://apt.repos.intel.com/mkl all/main amd64 intel-conda-mkl-linux-64-shadow-package-2020.0-166 amd64 2020.0-166 [8,614 B]
# Get:13 https://apt.repos.intel.com/mkl all/main amd64 intel-conda-mkl-include-linux-64-shadow-package-2020.0-166 amd64 2020.0-166 [9,042 B]
# Get:14 https://apt.repos.intel.com/mkl all/main amd64 intel-conda-mkl-devel-linux-64-shadow-package-2020.0-166 amd64 2020.0-166 [8,108 B]
# Get:15 https://apt.repos.intel.com/mkl all/main amd64 intel-conda-mkl-static-linux-64-shadow-package-2020.0-166 amd64 2020.0-166 [8,510 B]
# Get:16 https://apt.repos.intel.com/mkl all/main amd64 intel-mkl-cluster-rt-2020.0-166 amd64 2020.0-166 [4,005 kB]
# Get:17 https://apt.repos.intel.com/mkl all/main amd64 intel-mkl-cluster-2020.0-166 amd64 2020.0-166 [4,009 kB]
# Get:18 https://apt.repos.intel.com/mkl all/main amd64 intel-mkl-common-c-2020.0-166 all 2020.0-166 [1,794 kB]
# Get:19 https://apt.repos.intel.com/mkl all/main amd64 intel-mkl-cluster-c-2020.0-166 all 2020.0-166 [1,640 B]
# Get:20 https://apt.repos.intel.com/mkl all/main amd64 intel-mkl-common-f-2020.0-166 all 2020.0-166 [1,630 kB]
# Get:21 https://apt.repos.intel.com/mkl all/main amd64 intel-mkl-cluster-f-2020.0-166 all 2020.0-166 [1,640 B]
# Get:22 https://apt.repos.intel.com/mkl all/main amd64 intel-mkl-common-ps-2020.0-166 all 2020.0-166 [60.5 kB]
# Get:23 https://apt.repos.intel.com/mkl all/main amd64 intel-mkl-doc-ps-2020 all 2020.4-304 [69.3 kB]
# Get:24 https://apt.repos.intel.com/mkl all/main amd64 intel-mkl-common-c-ps-2020.0-166 all 2020.0-166 [26.9 kB]
# Get:25 https://apt.repos.intel.com/mkl all/main amd64 intel-mkl-core-c-2020.0-166 amd64 2020.0-166 [1,640 B]
# Get:26 https://apt.repos.intel.com/mkl all/main amd64 intel-mkl-core-f-2020.0-166 amd64 2020.0-166 [1,640 B]
# Get:27 https://apt.repos.intel.com/mkl all/main amd64 intel-mkl-core-ps-2020.0-166 amd64 2020.0-166 [6,353 kB]
# Get:28 https://apt.repos.intel.com/mkl all/main amd64 intel-mkl-f95-common-2020.0-166 all 2020.0-166 [131 kB]
# Get:29 https://apt.repos.intel.com/mkl all/main amd64 intel-mkl-f95-2020.0-166 amd64 2020.0-166 [1,768 kB]
# Get:30 https://apt.repos.intel.com/mkl all/main amd64 intel-mkl-gnu-rt-2020.0-166 amd64 2020.0-166 [3,879 kB]
# Get:31 https://apt.repos.intel.com/mkl all/main amd64 intel-mkl-gnu-2020.0-166 amd64 2020.0-166 [3,446 kB]
# Get:32 https://apt.repos.intel.com/mkl all/main amd64 intel-mkl-gnu-c-2020.0-166 amd64 2020.0-166 [1,640 B]
# Get:33 https://apt.repos.intel.com/mkl all/main amd64 intel-mkl-gnu-f-rt-2020.0-166 amd64 2020.0-166 [2,838 kB]
# Get:34 https://apt.repos.intel.com/mkl all/main amd64 intel-mkl-gnu-f-2020.0-166 amd64 2020.0-166 [1,440 kB]
# Get:35 https://apt.repos.intel.com/mkl all/main amd64 intel-mkl-pgi-rt-2020.0-166 amd64 2020.0-166 [5,213 kB]
# Get:36 https://apt.repos.intel.com/mkl all/main amd64 intel-mkl-pgi-2020.0-166 amd64 2020.0-166 [4,914 kB]
# Get:37 https://apt.repos.intel.com/mkl all/main amd64 intel-mkl-pgi-c-2020.0-166 amd64 2020.0-166 [1,642 B]
# Get:38 https://apt.repos.intel.com/mkl all/main amd64 intel-mkl-psxe-2020.0-088 all 2020.0-088 [2,056 B]
# Get:39 https://apt.repos.intel.com/mkl all/main amd64 intel-mkl-tbb-rt-2020.0-166 amd64 2020.0-166 [4,638 kB]
# Get:40 https://apt.repos.intel.com/mkl all/main amd64 intel-mkl-tbb-2020.0-166 amd64 2020.0-166 [4,244 kB]
# Get:41 https://apt.repos.intel.com/mkl all/main amd64 intel-psxe-common-doc-2020 all 2020.1-102 [5,904 B]
# Get:42 https://apt.repos.intel.com/mkl all/main amd64 intel-psxe-common-2020.0-088 all 2020.0-088 [4,948 B]
# Get:43 https://apt.repos.intel.com/mkl all/main amd64 intel-mkl-64bit-2020.0-088 amd64 2020.0-088 [2,148 B]
# Fetched 300 MB in 45s (6,606 kB/s)
# Extracting templates from packages: 100%
# Selecting previously unselected package intel-comp-l-all-vars-19.1.0-166.
# (Reading database ... 128130 files and directories currently installed.)
# Preparing to unpack .../00-intel-comp-l-all-vars-19.1.0-166_19.1.0-166_all.deb ...
# Unpacking intel-comp-l-all-vars-19.1.0-166 (19.1.0-166) ...
# Selecting previously unselected package intel-comp-nomcu-vars-19.1.0-166.
# Preparing to unpack .../01-intel-comp-nomcu-vars-19.1.0-166_19.1.0-166_all.deb ...
# Unpacking intel-comp-nomcu-vars-19.1.0-166 (19.1.0-166) ...
# Selecting previously unselected package intel-conda-index-tool-19.1.0-166.
# Preparing to unpack .../02-intel-conda-index-tool-19.1.0-166_19.1.0-166_amd64.deb ...
# Unpacking intel-conda-index-tool-19.1.0-166 (19.1.0-166) ...
# Selecting previously unselected package intel-conda-intel-openmp-linux-64-shadow-package-19.1.0-166.
# Preparing to unpack .../03-intel-conda-intel-openmp-linux-64-shadow-package-19.1.0-166_19.1.0-166_amd64.deb ...
# Unpacking intel-conda-intel-openmp-linux-64-shadow-package-19.1.0-166 (19.1.0-166) ...
# Selecting previously unselected package intel-tbb-libs-2020.0-166.
# Preparing to unpack .../04-intel-tbb-libs-2020.0-166_2020.0-166_amd64.deb ...
# Unpacking intel-tbb-libs-2020.0-166 (2020.0-166) ...
# Selecting previously unselected package intel-conda-tbb-linux-64-shadow-package-2020.0-166.
# Preparing to unpack .../05-intel-conda-tbb-linux-64-shadow-package-2020.0-166_2020.0-166_amd64.deb ...
# Unpacking intel-conda-tbb-linux-64-shadow-package-2020.0-166 (2020.0-166) ...
# Selecting previously unselected package intel-openmp-19.1.0-166.
# Preparing to unpack .../06-intel-openmp-19.1.0-166_19.1.0-166_amd64.deb ...
# Unpacking intel-openmp-19.1.0-166 (19.1.0-166) ...
# Selecting previously unselected package intel-mkl-doc-2020.
# Preparing to unpack .../07-intel-mkl-doc-2020_2020.4-304_all.deb ...
# Unpacking intel-mkl-doc-2020 (2020.4-304) ...
# Selecting previously unselected package intel-mkl-common-2020.0-166.
# Preparing to unpack .../08-intel-mkl-common-2020.0-166_2020.0-166_all.deb ...
# Unpacking intel-mkl-common-2020.0-166 (2020.0-166) ...
# Selecting previously unselected package intel-mkl-core-rt-2020.0-166.
# Preparing to unpack .../09-intel-mkl-core-rt-2020.0-166_2020.0-166_amd64.deb ...
# Unpacking intel-mkl-core-rt-2020.0-166 (2020.0-166) ...
# Selecting previously unselected package intel-mkl-core-2020.0-166.
# Preparing to unpack .../10-intel-mkl-core-2020.0-166_2020.0-166_amd64.deb ...
# Unpacking intel-mkl-core-2020.0-166 (2020.0-166) ...
# Selecting previously unselected package intel-conda-mkl-linux-64-shadow-package-2020.0-166.
# Preparing to unpack .../11-intel-conda-mkl-linux-64-shadow-package-2020.0-166_2020.0-166_amd64.deb ...
# Unpacking intel-conda-mkl-linux-64-shadow-package-2020.0-166 (2020.0-166) ...
# Selecting previously unselected package intel-conda-mkl-include-linux-64-shadow-package-2020.0-166.
# Preparing to unpack .../12-intel-conda-mkl-include-linux-64-shadow-package-2020.0-166_2020.0-166_amd64.deb ...
# Unpacking intel-conda-mkl-include-linux-64-shadow-package-2020.0-166 (2020.0-166) ...
# Selecting previously unselected package intel-conda-mkl-devel-linux-64-shadow-package-2020.0-166.
# Preparing to unpack .../13-intel-conda-mkl-devel-linux-64-shadow-package-2020.0-166_2020.0-166_amd64.deb ...
# Unpacking intel-conda-mkl-devel-linux-64-shadow-package-2020.0-166 (2020.0-166) ...
# Selecting previously unselected package intel-conda-mkl-static-linux-64-shadow-package-2020.0-166.
# Preparing to unpack .../14-intel-conda-mkl-static-linux-64-shadow-package-2020.0-166_2020.0-166_amd64.deb ...
# Unpacking intel-conda-mkl-static-linux-64-shadow-package-2020.0-166 (2020.0-166) ...
# Selecting previously unselected package intel-mkl-cluster-rt-2020.0-166.
# Preparing to unpack .../15-intel-mkl-cluster-rt-2020.0-166_2020.0-166_amd64.deb ...
# Unpacking intel-mkl-cluster-rt-2020.0-166 (2020.0-166) ...
# Selecting previously unselected package intel-mkl-cluster-2020.0-166.
# Preparing to unpack .../16-intel-mkl-cluster-2020.0-166_2020.0-166_amd64.deb ...
# Unpacking intel-mkl-cluster-2020.0-166 (2020.0-166) ...
# Selecting previously unselected package intel-mkl-common-c-2020.0-166.
# Preparing to unpack .../17-intel-mkl-common-c-2020.0-166_2020.0-166_all.deb ...
# Unpacking intel-mkl-common-c-2020.0-166 (2020.0-166) ...
# Selecting previously unselected package intel-mkl-cluster-c-2020.0-166.
# Preparing to unpack .../18-intel-mkl-cluster-c-2020.0-166_2020.0-166_all.deb ...
# Unpacking intel-mkl-cluster-c-2020.0-166 (2020.0-166) ...
# Selecting previously unselected package intel-mkl-common-f-2020.0-166.
# Preparing to unpack .../19-intel-mkl-common-f-2020.0-166_2020.0-166_all.deb ...
# Unpacking intel-mkl-common-f-2020.0-166 (2020.0-166) ...
# Selecting previously unselected package intel-mkl-cluster-f-2020.0-166.
# Preparing to unpack .../20-intel-mkl-cluster-f-2020.0-166_2020.0-166_all.deb ...
# Unpacking intel-mkl-cluster-f-2020.0-166 (2020.0-166) ...
# Selecting previously unselected package intel-mkl-common-ps-2020.0-166.
# Preparing to unpack .../21-intel-mkl-common-ps-2020.0-166_2020.0-166_all.deb ...
# Unpacking intel-mkl-common-ps-2020.0-166 (2020.0-166) ...
# Selecting previously unselected package intel-mkl-doc-ps-2020.
# Preparing to unpack .../22-intel-mkl-doc-ps-2020_2020.4-304_all.deb ...
# Unpacking intel-mkl-doc-ps-2020 (2020.4-304) ...
# Selecting previously unselected package intel-mkl-common-c-ps-2020.0-166.
# Preparing to unpack .../23-intel-mkl-common-c-ps-2020.0-166_2020.0-166_all.deb ...
# Unpacking intel-mkl-common-c-ps-2020.0-166 (2020.0-166) ...
# Selecting previously unselected package intel-mkl-core-c-2020.0-166.
# Preparing to unpack .../24-intel-mkl-core-c-2020.0-166_2020.0-166_amd64.deb ...
# Unpacking intel-mkl-core-c-2020.0-166 (2020.0-166) ...
# Selecting previously unselected package intel-mkl-core-f-2020.0-166.
# Preparing to unpack .../25-intel-mkl-core-f-2020.0-166_2020.0-166_amd64.deb ...
# Unpacking intel-mkl-core-f-2020.0-166 (2020.0-166) ...
# Selecting previously unselected package intel-mkl-core-ps-2020.0-166.
# Preparing to unpack .../26-intel-mkl-core-ps-2020.0-166_2020.0-166_amd64.deb ...
# Unpacking intel-mkl-core-ps-2020.0-166 (2020.0-166) ...
# Selecting previously unselected package intel-mkl-f95-common-2020.0-166.
# Preparing to unpack .../27-intel-mkl-f95-common-2020.0-166_2020.0-166_all.deb ...
# Unpacking intel-mkl-f95-common-2020.0-166 (2020.0-166) ...
# Selecting previously unselected package intel-mkl-f95-2020.0-166.
# Preparing to unpack .../28-intel-mkl-f95-2020.0-166_2020.0-166_amd64.deb ...
# Unpacking intel-mkl-f95-2020.0-166 (2020.0-166) ...
# Selecting previously unselected package intel-mkl-gnu-rt-2020.0-166.
# Preparing to unpack .../29-intel-mkl-gnu-rt-2020.0-166_2020.0-166_amd64.deb ...
# Unpacking intel-mkl-gnu-rt-2020.0-166 (2020.0-166) ...
# Selecting previously unselected package intel-mkl-gnu-2020.0-166.
# Preparing to unpack .../30-intel-mkl-gnu-2020.0-166_2020.0-166_amd64.deb ...
# Unpacking intel-mkl-gnu-2020.0-166 (2020.0-166) ...
# Selecting previously unselected package intel-mkl-gnu-c-2020.0-166.
# Preparing to unpack .../31-intel-mkl-gnu-c-2020.0-166_2020.0-166_amd64.deb ...
# Unpacking intel-mkl-gnu-c-2020.0-166 (2020.0-166) ...
# Selecting previously unselected package intel-mkl-gnu-f-rt-2020.0-166.
# Preparing to unpack .../32-intel-mkl-gnu-f-rt-2020.0-166_2020.0-166_amd64.deb ...
# Unpacking intel-mkl-gnu-f-rt-2020.0-166 (2020.0-166) ...
# Selecting previously unselected package intel-mkl-gnu-f-2020.0-166.
# Preparing to unpack .../33-intel-mkl-gnu-f-2020.0-166_2020.0-166_amd64.deb ...
# Unpacking intel-mkl-gnu-f-2020.0-166 (2020.0-166) ...
# Selecting previously unselected package intel-mkl-pgi-rt-2020.0-166.
# Preparing to unpack .../34-intel-mkl-pgi-rt-2020.0-166_2020.0-166_amd64.deb ...
# Unpacking intel-mkl-pgi-rt-2020.0-166 (2020.0-166) ...
# Selecting previously unselected package intel-mkl-pgi-2020.0-166.
# Preparing to unpack .../35-intel-mkl-pgi-2020.0-166_2020.0-166_amd64.deb ...
# Unpacking intel-mkl-pgi-2020.0-166 (2020.0-166) ...
# Selecting previously unselected package intel-mkl-pgi-c-2020.0-166.
# Preparing to unpack .../36-intel-mkl-pgi-c-2020.0-166_2020.0-166_amd64.deb ...
# Unpacking intel-mkl-pgi-c-2020.0-166 (2020.0-166) ...
# Selecting previously unselected package intel-mkl-psxe-2020.0-088.
# Preparing to unpack .../37-intel-mkl-psxe-2020.0-088_2020.0-088_all.deb ...
# Unpacking intel-mkl-psxe-2020.0-088 (2020.0-088) ...
# Selecting previously unselected package intel-mkl-tbb-rt-2020.0-166.
# Preparing to unpack .../38-intel-mkl-tbb-rt-2020.0-166_2020.0-166_amd64.deb ...
# Unpacking intel-mkl-tbb-rt-2020.0-166 (2020.0-166) ...
# Selecting previously unselected package intel-mkl-tbb-2020.0-166.
# Preparing to unpack .../39-intel-mkl-tbb-2020.0-166_2020.0-166_amd64.deb ...
# Unpacking intel-mkl-tbb-2020.0-166 (2020.0-166) ...
# Selecting previously unselected package intel-psxe-common-doc-2020.
# Preparing to unpack .../40-intel-psxe-common-doc-2020_2020.1-102_all.deb ...
# Unpacking intel-psxe-common-doc-2020 (2020.1-102) ...
# Selecting previously unselected package intel-psxe-common-2020.0-088.
# Preparing to unpack .../41-intel-psxe-common-2020.0-088_2020.0-088_all.deb ...
# Unpacking intel-psxe-common-2020.0-088 (2020.0-088) ...
# Selecting previously unselected package intel-mkl-64bit-2020.0-088.
# Preparing to unpack .../42-intel-mkl-64bit-2020.0-088_2020.0-088_amd64.deb ...
# Unpacking intel-mkl-64bit-2020.0-088 (2020.0-088) ...
# Setting up intel-psxe-common-doc-2020 (2020.1-102) ...
# Setting up intel-openmp-19.1.0-166 (19.1.0-166) ...
# Setting up intel-psxe-common-2020.0-088 (2020.0-088) ...
# Setting up intel-conda-index-tool-19.1.0-166 (19.1.0-166) ...
# Setting up intel-comp-l-all-vars-19.1.0-166 (19.1.0-166) ...
# Setting up intel-mkl-doc-2020 (2020.4-304) ...
# Setting up intel-tbb-libs-2020.0-166 (2020.0-166) ...
# Setting up intel-conda-tbb-linux-64-shadow-package-2020.0-166 (2020.0-166) ...
# Setting up intel-comp-nomcu-vars-19.1.0-166 (19.1.0-166) ...
# Setting up intel-mkl-psxe-2020.0-088 (2020.0-088) ...
# Setting up intel-mkl-doc-ps-2020 (2020.4-304) ...
# Setting up intel-conda-intel-openmp-linux-64-shadow-package-19.1.0-166 (19.1.0-166) ...
# Setting up intel-mkl-common-2020.0-166 (2020.0-166) ...
# Setting up intel-mkl-core-rt-2020.0-166 (2020.0-166) ...
# Setting up intel-mkl-pgi-rt-2020.0-166 (2020.0-166) ...
# Setting up intel-mkl-common-ps-2020.0-166 (2020.0-166) ...
# Setting up intel-mkl-common-c-2020.0-166 (2020.0-166) ...
# Setting up intel-mkl-common-f-2020.0-166 (2020.0-166) ...
# Setting up intel-mkl-cluster-rt-2020.0-166 (2020.0-166) ...
# Setting up intel-mkl-gnu-rt-2020.0-166 (2020.0-166) ...
# Setting up intel-mkl-core-2020.0-166 (2020.0-166) ...
# Setting up intel-mkl-f95-common-2020.0-166 (2020.0-166) ...
# Setting up intel-mkl-tbb-rt-2020.0-166 (2020.0-166) ...
# Setting up intel-mkl-core-f-2020.0-166 (2020.0-166) ...
# Setting up intel-mkl-core-c-2020.0-166 (2020.0-166) ...
# Setting up intel-mkl-common-c-ps-2020.0-166 (2020.0-166) ...
# Setting up intel-mkl-f95-2020.0-166 (2020.0-166) ...
# Setting up intel-mkl-core-ps-2020.0-166 (2020.0-166) ...
# Setting up intel-mkl-cluster-2020.0-166 (2020.0-166) ...
# Setting up intel-mkl-gnu-2020.0-166 (2020.0-166) ...
# Setting up intel-mkl-gnu-f-rt-2020.0-166 (2020.0-166) ...
# Setting up intel-mkl-pgi-2020.0-166 (2020.0-166) ...
# Setting up intel-mkl-gnu-f-2020.0-166 (2020.0-166) ...
# Setting up intel-mkl-gnu-c-2020.0-166 (2020.0-166) ...
# Setting up intel-mkl-cluster-f-2020.0-166 (2020.0-166) ...
# Setting up intel-mkl-cluster-c-2020.0-166 (2020.0-166) ...
# Setting up intel-conda-mkl-include-linux-64-shadow-package-2020.0-166 (2020.0-166) ...
# Setting up intel-conda-mkl-linux-64-shadow-package-2020.0-166 (2020.0-166) ...
# Setting up intel-mkl-tbb-2020.0-166 (2020.0-166) ...
# Setting up intel-mkl-pgi-c-2020.0-166 (2020.0-166) ...
# Setting up intel-conda-mkl-devel-linux-64-shadow-package-2020.0-166 (2020.0-166) ...
# Setting up intel-conda-mkl-static-linux-64-shadow-package-2020.0-166 (2020.0-166) ...
# Setting up intel-mkl-64bit-2020.0-088 (2020.0-088) ...
# ./kaldi/tools/extras/install_mkl.sh: Configuring ld runtime bindings
# + echo '/opt/intel/lib/intel64
# /opt/intel/mkl/lib/intel64'
# + ldconfig
# ./kaldi/tools/extras/install_mkl.sh: MKL package intel-mkl-64bit-2020.0-088 was successfully installed

# %%
# !./kaldi/tools/extras/check_dependencies.sh
# Out:
# ./kaldi/tools/extras/check_dependencies.sh: sox is not installed.
# ./kaldi/tools/extras/check_dependencies.sh: neither libtoolize nor glibtoolize is installed
# ./kaldi/tools/extras/check_dependencies.sh: subversion is not installed
# ./kaldi/tools/extras/check_dependencies.sh: python2.7 is installed, but the python2 binary does not exist. Creating a symlink and adding this to tools/env.sh
# ./kaldi/tools/extras/check_dependencies.sh: WARNING python 2.7 is not the default python. We fixed this by adding a correct symlink more prominently on the path.
#  ... If you really want to use python 3.8.10 as default, add an empty file /content/sample_data/python/.use_default_python and run this script again.
# ./kaldi/tools/extras/check_dependencies.sh: Some prerequisites are missing; install them using the command:
#   sudo apt-get install sox libtool subversion

# %%
# !./kaldi/tools/extras/check_dependencies.sh
# Out:
# ./kaldi/tools/extras/check_dependencies.sh: all OK.

# %%
# !make CXX=g++
# Out:
# make: *** No targets specified and no makefile found.  Stop.

# %%
# !cd kaldi/src/configure --shared
# Out:
# /bin/bash: line 0: cd: too many arguments

# %%
# !kaldi/src/configure --shared
# Out:
# You must run "configure" from the src/ directory.

# %%
# !ls ./kaldi/src/
# Out:
# base		decoder   gst-plugin  lm	 nnetbin     sgmm2bin
# bin		doc	  hmm	      lmbin	 NOTES	     tfrnnlm
# chain		Doxyfile  INSTALL     Makefile	 online      tfrnnlmbin
# chainbin	feat	  itf	      makefiles  online2     TODO
# configure	featbin   ivector     matrix	 online2bin  transform
# cudadecoder	fgmmbin   ivectorbin  nnet	 onlinebin   tree
# cudadecoderbin	fstbin	  kws	      nnet2	 probe	     util
# cudafeat	fstext	  kwsbin      nnet2bin	 rnnlm
# cudafeatbin	gmm	  lat	      nnet3	 rnnlmbin
# cudamatrix	gmmbin	  latbin      nnet3bin	 sgmm2

# %%
# !./kaldi/src/configure --shared
# Out:
# You must run "configure" from the src/ directory.

# %%
# !make CXX=g++
# Out:
# The version of configure script matches kaldi.mk version. Good.
# mkdir /content/sample_data/kaldi/src/lib
# make -C base
# make[1]: Entering directory '/content/sample_data/kaldi/src/base'
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o kaldi-math.o kaldi-math.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o kaldi-error.o kaldi-error.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o io-funcs.o io-funcs.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o kaldi-utils.o kaldi-utils.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o timer.o timer.cc
# ar -cr kaldi-base.a kaldi-math.o kaldi-error.o io-funcs.o kaldi-utils.o timer.o
# ranlib kaldi-base.a
# g++ -shared -o libkaldi-base.so -Wl,--as-needed  -Wl,-soname=libkaldi-base.so,--whole-archive kaldi-base.a -Wl,--no-whole-archive -Wl,-rpath=/content/sample_data/kaldi/tools/openfst-1.7.2/lib -rdynamic  -Wl,-rpath=/content/sample_data/kaldi/src/lib  /content/sample_data/kaldi/tools/openfst-1.7.2/lib/libfst.so -L/opt/intel/mkl/lib/intel64 -Wl,-rpath=/opt/intel/mkl/lib/intel64 -l:libmkl_intel_lp64.so -l:libmkl_core.so -l:libmkl_sequential.so -ldl -lpthread -lm -lm -lpthread -ldl
# ln -sf /content/sample_data/kaldi/src/base/libkaldi-base.so /content/sample_data/kaldi/src/lib/libkaldi-base.so
# make[1]: Leaving directory '/content/sample_data/kaldi/src/base'
# make -C matrix
# make[1]: Entering directory '/content/sample_data/kaldi/src/matrix'
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o kaldi-matrix.o kaldi-matrix.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o kaldi-vector.o kaldi-vector.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o packed-matrix.o packed-matrix.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o sp-matrix.o sp-matrix.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o tp-matrix.o tp-matrix.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o matrix-functions.o matrix-functions.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o qr.o qr.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o srfft.o srfft.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o compressed-matrix.o compressed-matrix.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o sparse-matrix.o sparse-matrix.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o optimization.o optimization.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o numpy-array.o numpy-array.cc
# ar -cr kaldi-matrix.a kaldi-matrix.o kaldi-vector.o packed-matrix.o sp-matrix.o tp-matrix.o matrix-functions.o qr.o srfft.o compressed-matrix.o sparse-matrix.o optimization.o numpy-array.o
# ranlib kaldi-matrix.a
# g++ -shared -o libkaldi-matrix.so -Wl,--as-needed  -Wl,-soname=libkaldi-matrix.so,--whole-archive kaldi-matrix.a -Wl,--no-whole-archive -Wl,-rpath=/content/sample_data/kaldi/tools/openfst-1.7.2/lib -rdynamic  -Wl,-rpath=/content/sample_data/kaldi/src/lib  ../base/libkaldi-base.so /content/sample_data/kaldi/tools/openfst-1.7.2/lib/libfst.so -L/opt/intel/mkl/lib/intel64 -Wl,-rpath=/opt/intel/mkl/lib/intel64 -l:libmkl_intel_lp64.so -l:libmkl_core.so -l:libmkl_sequential.so -ldl -lpthread -lm -lm -lpthread -ldl
# ln -sf /content/sample_data/kaldi/src/matrix/libkaldi-matrix.so /content/sample_data/kaldi/src/lib/libkaldi-matrix.so
# make[1]: Leaving directory '/content/sample_data/kaldi/src/matrix'
# make -C util
# make[1]: Entering directory '/content/sample_data/kaldi/src/util'
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o text-utils.o text-utils.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o kaldi-io.o kaldi-io.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o kaldi-holder.o kaldi-holder.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o kaldi-table.o kaldi-table.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o parse-options.o parse-options.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o simple-options.o simple-options.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o simple-io-funcs.o simple-io-funcs.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o kaldi-semaphore.o kaldi-semaphore.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o kaldi-thread.o kaldi-thread.cc
# ar -cr kaldi-util.a text-utils.o kaldi-io.o kaldi-holder.o kaldi-table.o parse-options.o simple-options.o simple-io-funcs.o kaldi-semaphore.o kaldi-thread.o
# ranlib kaldi-util.a
# g++ -shared -o libkaldi-util.so -Wl,--as-needed  -Wl,-soname=libkaldi-util.so,--whole-archive kaldi-util.a -Wl,--no-whole-archive -Wl,-rpath=/content/sample_data/kaldi/tools/openfst-1.7.2/lib -rdynamic  -Wl,-rpath=/content/sample_data/kaldi/src/lib  ../matrix/libkaldi-matrix.so  ../base/libkaldi-base.so /content/sample_data/kaldi/tools/openfst-1.7.2/lib/libfst.so -L/opt/intel/mkl/lib/intel64 -Wl,-rpath=/opt/intel/mkl/lib/intel64 -l:libmkl_intel_lp64.so -l:libmkl_core.so -l:libmkl_sequential.so -ldl -lpthread -lm -lm -lpthread -ldl
# ln -sf /content/sample_data/kaldi/src/util/libkaldi-util.so /content/sample_data/kaldi/src/lib/libkaldi-util.so
# make[1]: Leaving directory '/content/sample_data/kaldi/src/util'
# make -C tree
# make[1]: Entering directory '/content/sample_data/kaldi/src/tree'
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o event-map.o event-map.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o context-dep.o context-dep.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o clusterable-classes.o clusterable-classes.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o cluster-utils.o cluster-utils.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o build-tree-utils.o build-tree-utils.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o build-tree.o build-tree.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o build-tree-questions.o build-tree-questions.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o tree-renderer.o tree-renderer.cc
# ar -cr kaldi-tree.a event-map.o context-dep.o clusterable-classes.o cluster-utils.o build-tree-utils.o build-tree.o build-tree-questions.o tree-renderer.o
# ranlib kaldi-tree.a
# g++ -shared -o libkaldi-tree.so -Wl,--as-needed  -Wl,-soname=libkaldi-tree.so,--whole-archive kaldi-tree.a -Wl,--no-whole-archive -Wl,-rpath=/content/sample_data/kaldi/tools/openfst-1.7.2/lib -rdynamic  -Wl,-rpath=/content/sample_data/kaldi/src/lib  ../util/libkaldi-util.so  ../matrix/libkaldi-matrix.so  ../base/libkaldi-base.so /content/sample_data/kaldi/tools/openfst-1.7.2/lib/libfst.so -L/opt/intel/mkl/lib/intel64 -Wl,-rpath=/opt/intel/mkl/lib/intel64 -l:libmkl_intel_lp64.so -l:libmkl_core.so -l:libmkl_sequential.so -ldl -lpthread -lm -lm -lpthread -ldl
# ln -sf /content/sample_data/kaldi/src/tree/libkaldi-tree.so /content/sample_data/kaldi/src/lib/libkaldi-tree.so
# make[1]: Leaving directory '/content/sample_data/kaldi/src/tree'
# make -C fstext
# make[1]: Entering directory '/content/sample_data/kaldi/src/fstext'
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC -Wno-sign-compare -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o push-special.o push-special.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC -Wno-sign-compare -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o kaldi-fst-io.o kaldi-fst-io.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC -Wno-sign-compare -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o context-fst.o context-fst.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC -Wno-sign-compare -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o grammar-context-fst.o grammar-context-fst.cc
# ar -cr kaldi-fstext.a push-special.o kaldi-fst-io.o context-fst.o grammar-context-fst.o
# ranlib kaldi-fstext.a
# g++ -shared -o libkaldi-fstext.so -Wl,--as-needed  -Wl,-soname=libkaldi-fstext.so,--whole-archive kaldi-fstext.a -Wl,--no-whole-archive -Wl,-rpath=/content/sample_data/kaldi/tools/openfst-1.7.2/lib -rdynamic  -Wl,-rpath=/content/sample_data/kaldi/src/lib  ../tree/libkaldi-tree.so  ../util/libkaldi-util.so  ../matrix/libkaldi-matrix.so  ../base/libkaldi-base.so /content/sample_data/kaldi/tools/openfst-1.7.2/lib/libfst.so -L/opt/intel/mkl/lib/intel64 -Wl,-rpath=/opt/intel/mkl/lib/intel64 -l:libmkl_intel_lp64.so -l:libmkl_core.so -l:libmkl_sequential.so -ldl -lpthread -lm -lm -lpthread -ldl
# ln -sf /content/sample_data/kaldi/src/fstext/libkaldi-fstext.so /content/sample_data/kaldi/src/lib/libkaldi-fstext.so
# make[1]: Leaving directory '/content/sample_data/kaldi/src/fstext'
# make -C gmm
# make[1]: Entering directory '/content/sample_data/kaldi/src/gmm'
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o diag-gmm.o diag-gmm.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o diag-gmm-normal.o diag-gmm-normal.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o mle-diag-gmm.o mle-diag-gmm.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o am-diag-gmm.o am-diag-gmm.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o mle-am-diag-gmm.o mle-am-diag-gmm.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o full-gmm.o full-gmm.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o full-gmm-normal.o full-gmm-normal.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o mle-full-gmm.o mle-full-gmm.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o model-common.o model-common.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o decodable-am-diag-gmm.o decodable-am-diag-gmm.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o model-test-common.o model-test-common.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o ebw-diag-gmm.o ebw-diag-gmm.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o indirect-diff-diag-gmm.o indirect-diff-diag-gmm.cc
# ar -cr kaldi-gmm.a diag-gmm.o diag-gmm-normal.o mle-diag-gmm.o am-diag-gmm.o mle-am-diag-gmm.o full-gmm.o full-gmm-normal.o mle-full-gmm.o model-common.o decodable-am-diag-gmm.o model-test-common.o ebw-diag-gmm.o indirect-diff-diag-gmm.o
# ranlib kaldi-gmm.a
# g++ -shared -o libkaldi-gmm.so -Wl,--as-needed  -Wl,-soname=libkaldi-gmm.so,--whole-archive kaldi-gmm.a -Wl,--no-whole-archive -Wl,-rpath=/content/sample_data/kaldi/tools/openfst-1.7.2/lib -rdynamic  -Wl,-rpath=/content/sample_data/kaldi/src/lib  ../tree/libkaldi-tree.so  ../util/libkaldi-util.so  ../matrix/libkaldi-matrix.so  ../base/libkaldi-base.so /content/sample_data/kaldi/tools/openfst-1.7.2/lib/libfst.so -L/opt/intel/mkl/lib/intel64 -Wl,-rpath=/opt/intel/mkl/lib/intel64 -l:libmkl_intel_lp64.so -l:libmkl_core.so -l:libmkl_sequential.so -ldl -lpthread -lm -lm -lpthread -ldl
# ln -sf /content/sample_data/kaldi/src/gmm/libkaldi-gmm.so /content/sample_data/kaldi/src/lib/libkaldi-gmm.so
# make[1]: Leaving directory '/content/sample_data/kaldi/src/gmm'
# make -C hmm
# make[1]: Entering directory '/content/sample_data/kaldi/src/hmm'
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o hmm-topology.o hmm-topology.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o transition-model.o transition-model.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o hmm-utils.o hmm-utils.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o tree-accu.o tree-accu.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o posterior.o posterior.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o hmm-test-utils.o hmm-test-utils.cc
# ar -cr kaldi-hmm.a hmm-topology.o transition-model.o hmm-utils.o tree-accu.o posterior.o hmm-test-utils.o
# ranlib kaldi-hmm.a
# g++ -shared -o libkaldi-hmm.so -Wl,--as-needed  -Wl,-soname=libkaldi-hmm.so,--whole-archive kaldi-hmm.a -Wl,--no-whole-archive -Wl,-rpath=/content/sample_data/kaldi/tools/openfst-1.7.2/lib -rdynamic  -Wl,-rpath=/content/sample_data/kaldi/src/lib  ../tree/libkaldi-tree.so  ../util/libkaldi-util.so  ../matrix/libkaldi-matrix.so  ../base/libkaldi-base.so /content/sample_data/kaldi/tools/openfst-1.7.2/lib/libfst.so -L/opt/intel/mkl/lib/intel64 -Wl,-rpath=/opt/intel/mkl/lib/intel64 -l:libmkl_intel_lp64.so -l:libmkl_core.so -l:libmkl_sequential.so -ldl -lpthread -lm -lm -lpthread -ldl
# ln -sf /content/sample_data/kaldi/src/hmm/libkaldi-hmm.so /content/sample_data/kaldi/src/lib/libkaldi-hmm.so
# make[1]: Leaving directory '/content/sample_data/kaldi/src/hmm'
# make -C lat
# make[1]: Entering directory '/content/sample_data/kaldi/src/lat'
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC -Wno-sign-compare -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o kaldi-lattice.o kaldi-lattice.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC -Wno-sign-compare -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o lattice-functions.o lattice-functions.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC -Wno-sign-compare -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o lattice-functions-transition-model.o lattice-functions-transition-model.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC -Wno-sign-compare -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o word-align-lattice.o word-align-lattice.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC -Wno-sign-compare -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o phone-align-lattice.o phone-align-lattice.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC -Wno-sign-compare -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o word-align-lattice-lexicon.o word-align-lattice-lexicon.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC -Wno-sign-compare -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o sausages.o sausages.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC -Wno-sign-compare -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o push-lattice.o push-lattice.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC -Wno-sign-compare -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o minimize-lattice.o minimize-lattice.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC -Wno-sign-compare -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o determinize-lattice-pruned.o determinize-lattice-pruned.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC -Wno-sign-compare -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o confidence.o confidence.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC -Wno-sign-compare -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o compose-lattice-pruned.o compose-lattice-pruned.cc
# ar -cr kaldi-lat.a kaldi-lattice.o lattice-functions.o lattice-functions-transition-model.o word-align-lattice.o phone-align-lattice.o word-align-lattice-lexicon.o sausages.o push-lattice.o minimize-lattice.o determinize-lattice-pruned.o confidence.o compose-lattice-pruned.o
# ranlib kaldi-lat.a
# g++ -shared -o libkaldi-lat.so -Wl,--as-needed  -Wl,-soname=libkaldi-lat.so,--whole-archive kaldi-lat.a -Wl,--no-whole-archive -Wl,-rpath=/content/sample_data/kaldi/tools/openfst-1.7.2/lib -rdynamic  -Wl,-rpath=/content/sample_data/kaldi/src/lib  ../hmm/libkaldi-hmm.so  ../tree/libkaldi-tree.so  ../util/libkaldi-util.so  ../matrix/libkaldi-matrix.so  ../base/libkaldi-base.so /content/sample_data/kaldi/tools/openfst-1.7.2/lib/libfst.so -L/opt/intel/mkl/lib/intel64 -Wl,-rpath=/opt/intel/mkl/lib/intel64 -l:libmkl_intel_lp64.so -l:libmkl_core.so -l:libmkl_sequential.so -ldl -lpthread -lm -lm -lpthread -ldl
# ln -sf /content/sample_data/kaldi/src/lat/libkaldi-lat.so /content/sample_data/kaldi/src/lib/libkaldi-lat.so
# make[1]: Leaving directory '/content/sample_data/kaldi/src/lat'
# make -C transform
# make[1]: Entering directory '/content/sample_data/kaldi/src/transform'
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o regression-tree.o regression-tree.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o regtree-mllr-diag-gmm.o regtree-mllr-diag-gmm.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o lda-estimate.o lda-estimate.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o regtree-fmllr-diag-gmm.o regtree-fmllr-diag-gmm.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o cmvn.o cmvn.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o transform-common.o transform-common.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o fmllr-diag-gmm.o fmllr-diag-gmm.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o lvtln.o lvtln.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o mllt.o mllt.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o fmpe.o fmpe.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o basis-fmllr-diag-gmm.o basis-fmllr-diag-gmm.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o compressed-transform-stats.o compressed-transform-stats.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o fmllr-raw.o fmllr-raw.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o decodable-am-diag-gmm-regtree.o decodable-am-diag-gmm-regtree.cc
# ...
# #$ ptxas -arch=sm_86 -m64  --generate-line-info "/tmp/tmpxft_00019f44_00000000-6_batched-static-nnet3-kernels.compute_86.ptx"  -o "/tmp/tmpxft_00019f44_00000000-32_batched-static-nnet3-kernels.compute_86.cubin"
# #$ fatbinary -64 --ident="batched-static-nnet3-kernels.cu" --cmdline=" --generate-line-info " --cicc-cmdline="-generate-line-info -ftz=0 -prec_div=1 -prec_sqrt=1 -fmad=1 " "--image3=kind=elf,sm=35,file=/tmp/tmpxft_00019f44_00000000-17_batched-static-nnet3-kernels.compute_35.cubin" "--image3=kind=elf,sm=50,file=/tmp/tmpxft_00019f44_00000000-19_batched-static-nnet3-kernels.compute_50.cubin" "--image3=kind=elf,sm=52,file=/tmp/tmpxft_00019f44_00000000-21_batched-static-nnet3-kernels.compute_52.cubin" "--image3=kind=elf,sm=60,file=/tmp/tmpxft_00019f44_00000000-23_batched-static-nnet3-kernels.compute_60.cubin" "--image3=kind=elf,sm=61,file=/tmp/tmpxft_00019f44_00000000-25_batched-static-nnet3-kernels.compute_61.cubin" "--image3=kind=elf,sm=70,file=/tmp/tmpxft_00019f44_00000000-27_batched-static-nnet3-kernels.compute_70.cubin" "--image3=kind=elf,sm=75,file=/tmp/tmpxft_00019f44_00000000-29_batched-static-nnet3-kernels.compute_75.cubin" "--image3=kind=elf,sm=80,file=/tmp/tmpxft_00019f44_00000000-31_batched-static-nnet3-kernels.compute_80.cubin" "--image3=kind=elf,sm=86,file=/tmp/tmpxft_00019f44_00000000-32_batched-static-nnet3-kernels.compute_86.cubin" --embedded-fatbin="/tmp/tmpxft_00019f44_00000000-3_batched-static-nnet3-kernels.fatbin.c"
# #$ rm /tmp/tmpxft_00019f44_00000000-3_batched-static-nnet3-kernels.fatbin
# #$ g++ -std=c++14 -D__CUDA_ARCH_LIST__=350,500,520,600,610,700,750,800,860 -E -x c++ -D__CUDACC__ -D__NVCC__  -fPIC -I"/usr/local/cuda/include" -I"/content/sample_data/kaldi/tools/cub-1.8.0" -I".." -I"../" -I"/content/sample_data/kaldi/tools/openfst-1.7.2/include" "-I/usr/local/cuda/bin/../targets/x86_64-linux/include"   -isystem "/content/sample_data/kaldi/tools/openfst-1.7.2/include"  -D "HAVE_CUDA" -D "KALDI_DOUBLEPRECISION=0" -D "CUDA_API_PER_THREAD_DEFAULT_STREAM" -D__CUDACC_VER_MAJOR__=11 -D__CUDACC_VER_MINOR__=6 -D__CUDACC_VER_BUILD__=124 -D__CUDA_API_VER_MAJOR__=11 -D__CUDA_API_VER_MINOR__=6 -D__NVCC_DIAG_PRAGMA_SUPPORT__=1 -include "cuda_runtime.h" -m64 "batched-static-nnet3-kernels.cu" -o "/tmp/tmpxft_00019f44_00000000-5_batched-static-nnet3-kernels.cpp4.ii"
# #$ cudafe++ --c++14 --gnu_version=90400 --display_error_number --orig_src_file_name "batched-static-nnet3-kernels.cu" --orig_src_path_name "/content/sample_data/kaldi/src/cudadecoder/batched-static-nnet3-kernels.cu" --allow_managed  --m64 --parse_templates --gen_c_file_name "/tmp/tmpxft_00019f44_00000000-6_batched-static-nnet3-kernels.compute_86.cudafe1.cpp" --stub_file_name "tmpxft_00019f44_00000000-6_batched-static-nnet3-kernels.compute_86.cudafe1.stub.c" --module_id_file_name "/tmp/tmpxft_00019f44_00000000-4_batched-static-nnet3-kernels.module_id" "/tmp/tmpxft_00019f44_00000000-5_batched-static-nnet3-kernels.cpp4.ii"
# #$ g++ -std=c++14 -D__CUDA_ARCH__=860 -D__CUDA_ARCH_LIST__=350,500,520,600,610,700,750,800,860 -c -x c++  -DCUDA_DOUBLE_MATH_FUNCTIONS -fPIC -I"/usr/local/cuda/include" -I"/content/sample_data/kaldi/tools/cub-1.8.0" -I".." -I"../" -I"/content/sample_data/kaldi/tools/openfst-1.7.2/include" "-I/usr/local/cuda/bin/../targets/x86_64-linux/include"   -isystem "/content/sample_data/kaldi/tools/openfst-1.7.2/include" -m64 "/tmp/tmpxft_00019f44_00000000-6_batched-static-nnet3-kernels.compute_86.cudafe1.cpp" -o "batched-static-nnet3-kernels.o"
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC -Wno-sign-compare -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o cuda-online-pipeline-dynamic-batcher.o cuda-online-pipeline-dynamic-batcher.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC -Wno-sign-compare -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o decodable-cumatrix.o decodable-cumatrix.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC -Wno-sign-compare -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o cuda-pipeline-common.o cuda-pipeline-common.cc
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC -Wno-sign-compare -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o lattice-postprocessor.o lattice-postprocessor.cc
# ar -cr kaldi-cudadecoder.a cuda-decoder.o cuda-decoder-kernels.o cuda-fst.o batched-threaded-nnet3-cuda-online-pipeline.o batched-threaded-nnet3-cuda-pipeline.o batched-threaded-nnet3-cuda-pipeline2.o batched-static-nnet3.o batched-static-nnet3-kernels.o cuda-online-pipeline-dynamic-batcher.o decodable-cumatrix.o cuda-pipeline-common.o lattice-postprocessor.o
# ranlib kaldi-cudadecoder.a
# g++ -shared -o libkaldi-cudadecoder.so -Wl,--as-needed  -Wl,-soname=libkaldi-cudadecoder.so,--whole-archive kaldi-cudadecoder.a -Wl,--no-whole-archive -Wl,-rpath=/content/sample_data/kaldi/tools/openfst-1.7.2/lib -rdynamic  -L/usr/local/cuda/lib64/stubs -L/usr/local/cuda/lib64 -Wl,-rpath,/usr/local/cuda/lib64 -L/usr/local/cuda/lib/stubs -L/usr/local/cuda/lib -Wl,-rpath,/usr/local/cuda/lib -Wl,-rpath=/content/sample_data/kaldi/src/lib  ../cudamatrix/libkaldi-cudamatrix.so  ../base/libkaldi-base.so  ../matrix/libkaldi-matrix.so  ../lat/libkaldi-lat.so  ../util/libkaldi-util.so  ../matrix/libkaldi-matrix.so  ../gmm/libkaldi-gmm.so  ../fstext/libkaldi-fstext.so  ../hmm/libkaldi-hmm.so  ../gmm/libkaldi-gmm.so  ../transform/libkaldi-transform.so  ../tree/libkaldi-tree.so  ../online2/libkaldi-online2.so  ../nnet3/libkaldi-nnet3.so  ../cudafeat/libkaldi-cudafeat.so /content/sample_data/kaldi/tools/openfst-1.7.2/lib/libfst.so -L/opt/intel/mkl/lib/intel64 -Wl,-rpath=/opt/intel/mkl/lib/intel64 -l:libmkl_intel_lp64.so -l:libmkl_core.so -l:libmkl_sequential.so -ldl -lpthread -lm -lm -lpthread -ldl -lcuda -lcublas -lcusparse -lcusolver -lcudart -lcurand -lcufft -lnvToolsExt -lcusolver
# ln -sf /content/sample_data/kaldi/src/cudadecoder/libkaldi-cudadecoder.so /content/sample_data/kaldi/src/lib/libkaldi-cudadecoder.so
# make[1]: Leaving directory '/content/sample_data/kaldi/src/cudadecoder'
# make -C cudadecoderbin
# make[1]: Entering directory '/content/sample_data/kaldi/src/cudadecoderbin'
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o batched-wav-nnet3-cuda2.o batched-wav-nnet3-cuda2.cc
# g++ -Wl,-rpath=/content/sample_data/kaldi/tools/openfst-1.7.2/lib -rdynamic  -L/usr/local/cuda/lib64/stubs -L/usr/local/cuda/lib64 -Wl,-rpath,/usr/local/cuda/lib64 -L/usr/local/cuda/lib/stubs -L/usr/local/cuda/lib -Wl,-rpath,/usr/local/cuda/lib -Wl,-rpath=/content/sample_data/kaldi/src/lib  batched-wav-nnet3-cuda2.o  -lrt  ../cudadecoder/libkaldi-cudadecoder.so  ../cudafeat/libkaldi-cudafeat.so  ../online2/libkaldi-online2.so  ../ivector/libkaldi-ivector.so  ../nnet3/libkaldi-nnet3.so  ../chain/libkaldi-chain.so  ../nnet2/libkaldi-nnet2.so  ../cudamatrix/libkaldi-cudamatrix.so  ../decoder/libkaldi-decoder.so  ../lat/libkaldi-lat.so  ../fstext/libkaldi-fstext.so  ../hmm/libkaldi-hmm.so  ../feat/libkaldi-feat.so  ../transform/libkaldi-transform.so  ../gmm/libkaldi-gmm.so  ../tree/libkaldi-tree.so  ../util/libkaldi-util.so  ../matrix/libkaldi-matrix.so  ../base/libkaldi-base.so /content/sample_data/kaldi/tools/openfst-1.7.2/lib/libfst.so -L/opt/intel/mkl/lib/intel64 -Wl,-rpath=/opt/intel/mkl/lib/intel64 -l:libmkl_intel_lp64.so -l:libmkl_core.so -l:libmkl_sequential.so -ldl -lpthread -lm -lm -lpthread -ldl -lcuda -lcublas -lcusparse -lcusolver -lcudart -lcurand -lcufft -lnvToolsExt -lcusolver -o batched-wav-nnet3-cuda2
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o batched-wav-nnet3-cuda-online.o batched-wav-nnet3-cuda-online.cc
# g++ -Wl,-rpath=/content/sample_data/kaldi/tools/openfst-1.7.2/lib -rdynamic  -L/usr/local/cuda/lib64/stubs -L/usr/local/cuda/lib64 -Wl,-rpath,/usr/local/cuda/lib64 -L/usr/local/cuda/lib/stubs -L/usr/local/cuda/lib -Wl,-rpath,/usr/local/cuda/lib -Wl,-rpath=/content/sample_data/kaldi/src/lib  batched-wav-nnet3-cuda-online.o  -lrt  ../cudadecoder/libkaldi-cudadecoder.so  ../cudafeat/libkaldi-cudafeat.so  ../online2/libkaldi-online2.so  ../ivector/libkaldi-ivector.so  ../nnet3/libkaldi-nnet3.so  ../chain/libkaldi-chain.so  ../nnet2/libkaldi-nnet2.so  ../cudamatrix/libkaldi-cudamatrix.so  ../decoder/libkaldi-decoder.so  ../lat/libkaldi-lat.so  ../fstext/libkaldi-fstext.so  ../hmm/libkaldi-hmm.so  ../feat/libkaldi-feat.so  ../transform/libkaldi-transform.so  ../gmm/libkaldi-gmm.so  ../tree/libkaldi-tree.so  ../util/libkaldi-util.so  ../matrix/libkaldi-matrix.so  ../base/libkaldi-base.so /content/sample_data/kaldi/tools/openfst-1.7.2/lib/libfst.so -L/opt/intel/mkl/lib/intel64 -Wl,-rpath=/opt/intel/mkl/lib/intel64 -l:libmkl_intel_lp64.so -l:libmkl_core.so -l:libmkl_sequential.so -ldl -lpthread -lm -lm -lpthread -ldl -lcuda -lcublas -lcusparse -lcusolver -lcudart -lcurand -lcufft -lnvToolsExt -lcusolver -o batched-wav-nnet3-cuda-online
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o batched-wav-nnet3-cuda.o batched-wav-nnet3-cuda.cc
# g++ -Wl,-rpath=/content/sample_data/kaldi/tools/openfst-1.7.2/lib -rdynamic  -L/usr/local/cuda/lib64/stubs -L/usr/local/cuda/lib64 -Wl,-rpath,/usr/local/cuda/lib64 -L/usr/local/cuda/lib/stubs -L/usr/local/cuda/lib -Wl,-rpath,/usr/local/cuda/lib -Wl,-rpath=/content/sample_data/kaldi/src/lib  batched-wav-nnet3-cuda.o  -lrt  ../cudadecoder/libkaldi-cudadecoder.so  ../cudafeat/libkaldi-cudafeat.so  ../online2/libkaldi-online2.so  ../ivector/libkaldi-ivector.so  ../nnet3/libkaldi-nnet3.so  ../chain/libkaldi-chain.so  ../nnet2/libkaldi-nnet2.so  ../cudamatrix/libkaldi-cudamatrix.so  ../decoder/libkaldi-decoder.so  ../lat/libkaldi-lat.so  ../fstext/libkaldi-fstext.so  ../hmm/libkaldi-hmm.so  ../feat/libkaldi-feat.so  ../transform/libkaldi-transform.so  ../gmm/libkaldi-gmm.so  ../tree/libkaldi-tree.so  ../util/libkaldi-util.so  ../matrix/libkaldi-matrix.so  ../base/libkaldi-base.so /content/sample_data/kaldi/tools/openfst-1.7.2/lib/libfst.so -L/opt/intel/mkl/lib/intel64 -Wl,-rpath=/opt/intel/mkl/lib/intel64 -l:libmkl_intel_lp64.so -l:libmkl_core.so -l:libmkl_sequential.so -ldl -lpthread -lm -lm -lpthread -ldl -lcuda -lcublas -lcusparse -lcusolver -lcudart -lcurand -lcufft -lnvToolsExt -lcusolver -o batched-wav-nnet3-cuda
# make[1]: Leaving directory '/content/sample_data/kaldi/src/cudadecoderbin'
# make -C matrix test
# make[1]: Entering directory '/content/sample_data/kaldi/src/matrix'
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o matrix-lib-test.o matrix-lib-test.cc
# g++ -Wl,-rpath=/content/sample_data/kaldi/tools/openfst-1.7.2/lib -rdynamic  -Wl,-rpath=/content/sample_data/kaldi/src/lib  matrix-lib-test.o libkaldi-matrix.so   ../base/libkaldi-base.so /content/sample_data/kaldi/tools/openfst-1.7.2/lib/libfst.so -L/opt/intel/mkl/lib/intel64 -Wl,-rpath=/opt/intel/mkl/lib/intel64 -l:libmkl_intel_lp64.so -l:libmkl_core.so -l:libmkl_sequential.so -ldl -lpthread -lm -lm -lpthread -ldl -o matrix-lib-test
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o sparse-matrix-test.o sparse-matrix-test.cc
# g++ -Wl,-rpath=/content/sample_data/kaldi/tools/openfst-1.7.2/lib -rdynamic  -Wl,-rpath=/content/sample_data/kaldi/src/lib  sparse-matrix-test.o libkaldi-matrix.so   ../base/libkaldi-base.so /content/sample_data/kaldi/tools/openfst-1.7.2/lib/libfst.so -L/opt/intel/mkl/lib/intel64 -Wl,-rpath=/opt/intel/mkl/lib/intel64 -l:libmkl_intel_lp64.so -l:libmkl_core.so -l:libmkl_sequential.so -ldl -lpthread -lm -lm -lpthread -ldl -o sparse-matrix-test
# g++ -std=c++14 -I.. -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include -O1 -Wall -Wno-sign-compare -Wno-unused-local-typedefs -Wno-deprecated-declarations -Winit-self -DKALDI_DOUBLEPRECISION=0 -DHAVE_EXECINFO_H=1 -DHAVE_CXXABI_H -DHAVE_MKL -I/opt/intel/mkl/include -m64 -msse -msse2 -pthread -g -fPIC  -DHAVE_CUDA -I/usr/local/cuda/include -fPIC -pthread -isystem /content/sample_data/kaldi/tools/openfst-1.7.2/include   -c -o numpy-array-test.o numpy-array-test.cc
# g++ -Wl,-rpath=/content/sample_data/kaldi/tools/openfst-1.7.2/lib -rdynamic  -Wl,-rpath=/content/sample_data/kaldi/src/lib  numpy-array-test.o libkaldi-matrix.so   ../base/libkaldi-base.so /content/sample_data/kaldi/tools/openfst-1.7.2/lib/libfst.so -L/opt/intel/mkl/lib/intel64 -Wl,-rpath=/opt/intel/mkl/lib/intel64 -l:libmkl_intel_lp64.so -l:libmkl_core.so -l:libmkl_sequential.so -ldl -lpthread -lm -lm -lpthread -ldl -o numpy-array-test
# Running matrix-lib-test ... 1s... SUCCESS matrix-lib-test
# Running sparse-matrix-test ... 0s... SUCCESS sparse-matrix-test
# Running numpy-array-test ... 1s... SUCCESS numpy-array-test
# make[1]: Leaving directory '/content/sample_data/kaldi/src/matrix'
# Done

# %%
# !ls
# Out:
# anscombe.json		      env.sh	      mnist_train_small.csv
# california_housing_test.csv   kaldi	      python
# california_housing_train.csv  mnist_test.csv  README.md

# %%
# !sudo apt-get install sox libtool subversion
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-510
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   libapr1 libaprutil1 libopencore-amrnb0 libopencore-amrwb0 libserf-1-1
#   libsox-fmt-alsa libsox-fmt-base libsox3 libsvn1 libutf8proc2
# Suggested packages:
#   libsox-fmt-all libtool-doc gcj-jdk db5.3-util libapache2-mod-svn
#   subversion-tools
# The following NEW packages will be installed:
#   libapr1 libaprutil1 libopencore-amrnb0 libopencore-amrwb0 libserf-1-1
#   libsox-fmt-alsa libsox-fmt-base libsox3 libsvn1 libtool libutf8proc2 sox
#   subversion
# 0 upgraded, 13 newly installed, 0 to remove and 22 not upgraded.
# Need to get 3,029 kB of archives.
# After this operation, 13.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/main amd64 libapr1 amd64 1.6.5-1ubuntu1 [91.4 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libaprutil1 amd64 1.6.1-4ubuntu2.1 [84.9 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/universe amd64 libopencore-amrnb0 amd64 0.1.5-1 [94.8 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/universe amd64 libopencore-amrwb0 amd64 0.1.5-1 [49.1 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal/universe amd64 libserf-1-1 amd64 1.3.9-8build1 [45.2 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal/universe amd64 libsox3 amd64 14.4.2+git20190427-2 [226 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal/universe amd64 libsox-fmt-alsa amd64 14.4.2+git20190427-2 [10.5 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal/universe amd64 libsox-fmt-base amd64 14.4.2+git20190427-2 [31.5 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal/universe amd64 libutf8proc2 amd64 2.5.0-1 [50.0 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libsvn1 amd64 1.13.0-3ubuntu0.2 [1,260 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal/main amd64 libtool all 2.4.6-14 [161 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal/universe amd64 sox amd64 14.4.2+git20190427-2 [102 kB]
# Get:13 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 subversion amd64 1.13.0-3ubuntu0.2 [824 kB]
# Fetched 3,029 kB in 2s (1,921 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 13.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libapr1:amd64.
# (Reading database ... 130473 files and directories currently installed.)
# Preparing to unpack .../00-libapr1_1.6.5-1ubuntu1_amd64.deb ...
# Unpacking libapr1:amd64 (1.6.5-1ubuntu1) ...
# Selecting previously unselected package libaprutil1:amd64.
# Preparing to unpack .../01-libaprutil1_1.6.1-4ubuntu2.1_amd64.deb ...
# Unpacking libaprutil1:amd64 (1.6.1-4ubuntu2.1) ...
# Selecting previously unselected package libopencore-amrnb0:amd64.
# Preparing to unpack .../02-libopencore-amrnb0_0.1.5-1_amd64.deb ...
# Unpacking libopencore-amrnb0:amd64 (0.1.5-1) ...
# Selecting previously unselected package libopencore-amrwb0:amd64.
# Preparing to unpack .../03-libopencore-amrwb0_0.1.5-1_amd64.deb ...
# Unpacking libopencore-amrwb0:amd64 (0.1.5-1) ...
# Selecting previously unselected package libserf-1-1:amd64.
# Preparing to unpack .../04-libserf-1-1_1.3.9-8build1_amd64.deb ...
# Unpacking libserf-1-1:amd64 (1.3.9-8build1) ...
# Selecting previously unselected package libsox3:amd64.
# Preparing to unpack .../05-libsox3_14.4.2+git20190427-2_amd64.deb ...
# Unpacking libsox3:amd64 (14.4.2+git20190427-2) ...
# Selecting previously unselected package libsox-fmt-alsa:amd64.
# Preparing to unpack .../06-libsox-fmt-alsa_14.4.2+git20190427-2_amd64.deb ...
# Unpacking libsox-fmt-alsa:amd64 (14.4.2+git20190427-2) ...
# Selecting previously unselected package libsox-fmt-base:amd64.
# Preparing to unpack .../07-libsox-fmt-base_14.4.2+git20190427-2_amd64.deb ...
# Unpacking libsox-fmt-base:amd64 (14.4.2+git20190427-2) ...
# Selecting previously unselected package libutf8proc2:amd64.
# Preparing to unpack .../08-libutf8proc2_2.5.0-1_amd64.deb ...
# Unpacking libutf8proc2:amd64 (2.5.0-1) ...
# Selecting previously unselected package libsvn1:amd64.
# Preparing to unpack .../09-libsvn1_1.13.0-3ubuntu0.2_amd64.deb ...
# Unpacking libsvn1:amd64 (1.13.0-3ubuntu0.2) ...
# Selecting previously unselected package libtool.
# Preparing to unpack .../10-libtool_2.4.6-14_all.deb ...
# Unpacking libtool (2.4.6-14) ...
# Selecting previously unselected package sox.
# Preparing to unpack .../11-sox_14.4.2+git20190427-2_amd64.deb ...
# Unpacking sox (14.4.2+git20190427-2) ...
# Selecting previously unselected package subversion.
# Preparing to unpack .../12-subversion_1.13.0-3ubuntu0.2_amd64.deb ...
# Unpacking subversion (1.13.0-3ubuntu0.2) ...
# Setting up libsox3:amd64 (14.4.2+git20190427-2) ...
# Setting up libtool (2.4.6-14) ...
# Setting up libutf8proc2:amd64 (2.5.0-1) ...
# Setting up libapr1:amd64 (1.6.5-1ubuntu1) ...
# Setting up libopencore-amrwb0:amd64 (0.1.5-1) ...
# Setting up libsox-fmt-alsa:amd64 (14.4.2+git20190427-2) ...
# Setting up libopencore-amrnb0:amd64 (0.1.5-1) ...
# Setting up libsox-fmt-base:amd64 (14.4.2+git20190427-2) ...
# Setting up libaprutil1:amd64 (1.6.1-4ubuntu2.1) ...
# Setting up libserf-1-1:amd64 (1.3.9-8build1) ...
# Setting up sox (14.4.2+git20190427-2) ...
# Setting up libsvn1:amd64 (1.13.0-3ubuntu0.2) ...
# Setting up subversion (1.13.0-3ubuntu0.2) ...
# Processing triggers for mime-support (3.64ubuntu1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Processing triggers for man-db (2.9.1-1) ...

# %%
# !./kaldi/tools/extras/sox_sh
# Out:
# /bin/bash: ./kaldi/tools/extras/sox_sh: No such file or directory

# %%
# !cd ./kaldi/tools/extras | ls
# Out:
# anscombe.json		      kaldi		     README.md
# california_housing_test.csv   mnist_test.csv
# california_housing_train.csv  mnist_train_small.csv

# %%
# !cd ..

# %%
# !ls
# Out:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %%
# !cd ./

# %%
# !ls
# Out:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Qu'est-ce que Colab ?</h1>
# </div>
#
# Colab &#40;ou "Colaboratory"&#41; vous permet d'écrire et d'exécuter du code Python dans votre navigateur avec
# - Aucune configuration requise
# - Accès sans frais aux GPU
# - Partage facile
#
# Que vous soyez <strong>étudiant</strong>, <strong>data scientist</strong> ou <strong>chercheur en IA</strong>, Colab peut vous simplifier la tâche. Regardez la <a href="https://www.youtube.com/watch?v=inN8seMm7UI">présentation de Colab</a> pour en savoir plus ou commencez tout de suite.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## <strong>Premiers pas</strong>
# </div>
#
# Le document que vous consultez n'est pas une page Web statique, mais un environnement interactif appelé <strong>notebook Colab</strong>, qui vous permet d'écrire et d'exécuter du code.
#
# Voici par exemple une <strong>cellule de code</strong> avec un bref script en Python qui calcule une valeur, l'enregistre dans une variable et imprime le résultat :

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# Pour exécuter le code dans la cellule ci-dessus, sélectionnez-le en cliquant dessus, puis cliquez sur le bouton de lecture à gauche du code ou utilisez le raccourci clavier Commande/Ctrl+Entrée. Pour modifier le code, cliquez simplement sur la cellule.
#
# Les variables que vous définissez dans une cellule peuvent être utilisées par la suite dans d'autres cellules :

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# Les notebooks Colab vous permettent d'utiliser, dans un même document, du <strong>code exécutable</strong>, du <strong>texte enrichi</strong>, des <strong>images</strong>, du code <strong>HTML</strong>, du code <strong>LaTeX</strong> et bien plus. Lorsque vous créez des notebooks Colab, ils sont enregistrés dans votre compte Google Drive. Vous pouvez facilement les partager avec vos collaborateurs ou vos amis, qui peuvent alors y apporter des commentaires ou même les modifier. Pour en savoir plus, consultez la page <a href="/notebooks/basic_features_overview.ipynb">Présentation de Colaboratory</a>. Pour créer un notebook Colab, utilisez le menu "Fichier" ci-dessus ou le lien <a href="http://colab.research.google.com#create=true">Créer un notebook Colab</a>.
#
# Les notebooks Colab sont des notebooks Jupyter hébergés par Colab. Pour en savoir plus sur le projet Jupyter, consultez le site Web <a href="https://www.jupyter.org">jupyter.org</a>.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Science des données
# </div>
#
# Colab vous permet de tirer pleinement parti des bibliothèques populaires Python pour analyser et visualiser des données. La cellule de code ci-dessous utilise <strong>numpy</strong> pour générer des données aléatoires et <strong>matplotlib</strong> pour les visualiser. Pour modifier le code, cliquez simplement sur la cellule.

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()

# %% [markdown]
# Vous pouvez importer vos propres données dans les notebooks Colab depuis votre compte Google Drive, y compris depuis des feuilles de calcul, ainsi que depuis GitHub et de nombreuses autres sources. Pour en savoir plus sur l'importation de données et l'utilisation de Colab dans le domaine de la science des données, consultez les liens ci-dessous dans la section <a href="#working-with-data">Utiliser les données</a>.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Machine learning
# </div>
#
# Colab vous permet d'importer un ensemble de données d'images, d'entraîner un classificateur d'images sur cet ensemble et d'évaluer le modèle, tout cela avec <a href="https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb">quelques lignes de code</a>. Les notebooks Colab exécutent ce code sur les serveurs cloud de Google. Vous avez donc à votre disposition toute la puissance du matériel Google, y compris les <a href="#using-accelerated-hardware">GPU et TPU</a>, quelle que soit la puissance de votre ordinateur. Vous n'avez besoin que d'un navigateur.

# %% [markdown]
# Colab est très largement utilisé par la communauté du machine learning, par exemple dans les applications suivantes :
# - Premiers pas avec TensorFlow
# - Développement et entraînement de réseaux de neurones
# - Expérimentation avec les TPU
# - Dissémination de la recherche en IA
# - Création de tutoriels
#
# Pour voir comment les notebooks Colab sont utilisés dans des applications de machine learning, reportez-vous aux <a href="#machine-learning-examples">exemples de machine learning</a> ci-dessous.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Autres ressources
#
# ### Utiliser les notebooks dans Colab
#
# </div>
#
# - [Présentation de Colaboratory](/notebooks/basic_features_overview.ipynb)
# - [Guide de Markdown](/notebooks/markdown_guide.ipynb)
# - [Importer des bibliothèques et installer des dépendances](/notebooks/snippets/importing_libraries.ipynb)
# - [Enregistrer et charger des notebooks dans GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb)
# - [Formulaires interactifs](/notebooks/forms.ipynb)
# - [Widgets interactifs](/notebooks/widgets.ipynb)
# - <img src="/img/new.png" height="20px" align="left" hspace="4px" alt="New"></img>
#
# <div class="markdown-google-sans">
#
# <a name="working-with-data"></a>
# ### Utiliser les données
# </div>
#
# - [Chargement de données : Drive, Sheets et Google Cloud Storage](/notebooks/io.ipynb)
# - [Graphiques : visualiser les données](/notebooks/charts.ipynb)
# - [Premiers pas avec BigQuery](/notebooks/bigquery.ipynb)
#
# <div class="markdown-google-sans">
#
# ### Cours d'initiation au Machine Learning
#
# <div>
#
# Vous trouverez ci-dessous quelques-uns des notebooks de la formation Google en ligne sur le machine learning. Consultez la <a href="https://developers.google.com/machine-learning/crash-course/">formation complète en ligne</a> pour en savoir plus.
# - [Présentation du DataFrame pandas](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb)
# - [Régression linéaire avec tf.keras et des données synthétiques](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/linear_regression_with_synthetic_data.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="using-accelerated-hardware"></a>
# ### Utiliser le matériel accéléré
# </div>
#
# - [TensorFlow avec des GPU](/notebooks/gpu.ipynb)
# - [TensorFlow avec des TPU](/notebooks/tpu.ipynb)

# %%
# %cd ./Kaldi
# Out:
# [Errno 2] No such file or directory: './Kaldi'
# /

# %% [markdown]
# <div class="markdown-google-sans">
#
# <a name="machine-learning-examples"></a>
#
# ### Exemples
#
# </div>
#
# - <a href="https://colab.research.google.com/github/NVIDIA/NeMo/blob/stable/tutorials/VoiceSwapSample.ipynb">Échange de voix avec NeMo</a> : utilisez le kit Nvidia NeMo pour l'IA conversationnelle afin d'échanger une voix dans un fragment audio contre une voix générée par ordinateur.
#
# - <a href="https://tensorflow.org/hub/tutorials/tf2_image_retraining">Recyclage d'un classificateur d'images</a> : construisez un modèle Keras sur un classificateur d'images pré-entraîné pour faire la distinction entre différentes fleurs.
# - <a href="https://tensorflow.org/hub/tutorials/tf2_text_classification">Classification de texte</a> : classez des avis sur des films provenant de la base de données IMDB comme <em>positifs</em> ou <em>négatifs</em>.
# - <a href="https://tensorflow.org/hub/tutorials/tf2_arbitrary_image_stylization">Transfert de style</a> : utilisez le deep learning pour transférer un style d'une image à une autre.
# - <a href="https://tensorflow.org/hub/tutorials/retrieval_with_tf_hub_universal_encoder_qa">Questions/Réponses sur l'encodeur de phrases universel multilingue</a> : utilisez un modèle de machine learning afin de répondre aux questions issues de l'ensemble de données SQuAD.
# - <a href="https://tensorflow.org/hub/tutorials/tweening_conv3d">Interpolation vidéo</a> : prédisez ce qui s'est passé entre la première et la dernière image d'une vidéo.

# %%
# !sudo apt install git-all
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-510
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   apache2 apache2-bin apache2-data apache2-utils cvs cvsps dh-elpa-helper
#   elpa-dash elpa-ghub elpa-git-commit elpa-let-alist elpa-magit
#   elpa-magit-popup elpa-treepy elpa-with-editor emacs emacs-bin-common
#   emacs-common emacs-el emacs-gtk fonts-droid-fallback fonts-noto-mono
#   fonts-urw-base35 ghostscript git-cvs git-daemon-run git-doc git-el git-email
#   git-gui git-mediawiki git-svn gitk gitweb gsfonts imagemagick-6-common
#   install-info libalgorithm-c3-perl libapr1 libaprutil1
#   libaprutil1-dbd-sqlite3 libaprutil1-ldap libauthen-sasl-perl
#   libb-hooks-endofscope-perl libb-hooks-op-check-perl libcgi-fast-perl
#   libcgi-pm-perl libclass-c3-perl libclass-c3-xs-perl
#   libclass-data-inheritable-perl libclass-inspector-perl
#   libclass-method-modifiers-perl libclass-singleton-perl
#   libclass-xsaccessor-perl libcommon-sense-perl libdata-dump-perl
#   libdata-optlist-perl libdatetime-format-builder-perl
#   libdatetime-format-iso8601-perl libdatetime-format-strptime-perl
#   libdatetime-locale-perl libdatetime-perl libdatetime-timezone-perl
#   libdbd-sqlite3-perl libdbi-perl libdevel-callchecker-perl
#   libdevel-caller-perl libdevel-lexalias-perl libdevel-stacktrace-perl
#   libdigest-bubblebabble-perl libdigest-hmac-perl libdynaloader-functions-perl
#   libemail-valid-perl libencode-locale-perl libeval-closure-perl
#   libexception-class-perl libfcgi-perl libfile-listing-perl
#   libfile-sharedir-perl libfont-afm-perl libgs9 libgs9-common
#   libhtml-form-perl libhtml-format-perl libhtml-parser-perl
#   libhtml-tagset-perl libhtml-tree-perl libhttp-cookies-perl
#   libhttp-daemon-perl libhttp-date-perl libhttp-message-perl
#   libhttp-negotiate-perl libidn11 libijs-0.35 libio-html-perl
#   libio-socket-ssl-perl libjbig2dec0 libjson-perl libjson-xs-perl liblqr-1-0
#   liblua5.2-0 liblwp-mediatypes-perl liblwp-protocol-https-perl libm17n-0
#   libmagickcore-6.q16-6 libmagickwand-6.q16-6 libmailtools-perl
#   libmediawiki-api-perl libmodule-implementation-perl libmodule-runtime-perl
#   libmro-compat-perl libnamespace-autoclean-perl libnamespace-clean-perl
#   libnet-dns-perl libnet-dns-sec-perl libnet-domain-tld-perl libnet-http-perl
#   libnet-ip-perl libnet-libidn-perl libnet-smtp-ssl-perl libnet-ssleay-perl
#   libotf0 libpackage-stash-perl libpackage-stash-xs-perl libpadwalker-perl
#   libparams-classify-perl libparams-util-perl libparams-validate-perl
#   libparams-validationcompiler-perl libperl4-corelibs-perl libreadonly-perl
#   libref-util-perl libref-util-xs-perl librole-tiny-perl libserf-1-1
#   libspecio-perl libsub-exporter-perl libsub-exporter-progressive-perl
#   libsub-identify-perl libsub-install-perl libsub-name-perl libsub-quote-perl
#   libsvn-perl libsvn1 libterm-readkey-perl libtry-tiny-perl
#   libtypes-serialiser-perl liburi-perl libutf8proc2 libvariable-magic-perl
#   libwww-perl libwww-robotrules-perl libxstring-perl libyaml-libyaml-perl
#   libyaml-perl m17n-db netbase perl-openssl-defaults poppler-data runit
#   ssl-cert
# Suggested packages:
#   apache2-doc apache2-suexec-pristine | apache2-suexec-custom www-browser ufw
#   mksh rcs mailutils emacs-common-non-dfsg ncurses-term fonts-noto
#   fonts-freefont-otf | fonts-freefont-ttf fonts-texgyre ghostscript-x aspell
#   meld mediawiki subversion libgssapi-perl libclone-perl libmldbm-perl
#   libnet-daemon-perl libsql-statement-perl libcrypt-ssleay-perl m17n-docs
#   libmagickcore-6.q16-6-extra libscalar-number-perl libtest-fatal-perl
#   libauthen-ntlm-perl libyaml-shell-perl gawk poppler-utils
#   fonts-japanese-mincho | fonts-ipafont-mincho fonts-japanese-gothic
#   | fonts-ipafont-gothic fonts-arphic-ukai fonts-arphic-uming fonts-nanum
#   openssl-blacklist
# The following NEW packages will be installed:
#   apache2 apache2-bin apache2-data apache2-utils cvs cvsps dh-elpa-helper
#   elpa-dash elpa-ghub elpa-git-commit elpa-let-alist elpa-magit
#   elpa-magit-popup elpa-treepy elpa-with-editor emacs emacs-bin-common
#   emacs-common emacs-el emacs-gtk fonts-droid-fallback fonts-noto-mono
#   fonts-urw-base35 ghostscript git-all git-cvs git-daemon-run git-doc git-el
#   git-email git-gui git-mediawiki git-svn gitk gitweb gsfonts
#   imagemagick-6-common install-info libalgorithm-c3-perl libapr1 libaprutil1
#   libaprutil1-dbd-sqlite3 libaprutil1-ldap libauthen-sasl-perl
#   libb-hooks-endofscope-perl libb-hooks-op-check-perl libcgi-fast-perl
#   libcgi-pm-perl libclass-c3-perl libclass-c3-xs-perl
#   libclass-data-inheritable-perl libclass-inspector-perl
#   libclass-method-modifiers-perl libclass-singleton-perl
#   libclass-xsaccessor-perl libcommon-sense-perl libdata-dump-perl
#   libdata-optlist-perl libdatetime-format-builder-perl
#   libdatetime-format-iso8601-perl libdatetime-format-strptime-perl
#   libdatetime-locale-perl libdatetime-perl libdatetime-timezone-perl
#   libdbd-sqlite3-perl libdbi-perl libdevel-callchecker-perl
#   libdevel-caller-perl libdevel-lexalias-perl libdevel-stacktrace-perl
#   libdigest-bubblebabble-perl libdigest-hmac-perl libdynaloader-functions-perl
#   libemail-valid-perl libencode-locale-perl libeval-closure-perl
#   libexception-class-perl libfcgi-perl libfile-listing-perl
#   libfile-sharedir-perl libfont-afm-perl libgs9 libgs9-common
#   libhtml-form-perl libhtml-format-perl libhtml-parser-perl
#   libhtml-tagset-perl libhtml-tree-perl libhttp-cookies-perl
#   libhttp-daemon-perl libhttp-date-perl libhttp-message-perl
#   libhttp-negotiate-perl libidn11 libijs-0.35 libio-html-perl
#   libio-socket-ssl-perl libjbig2dec0 libjson-perl libjson-xs-perl liblqr-1-0
#   liblua5.2-0 liblwp-mediatypes-perl liblwp-protocol-https-perl libm17n-0
#   libmagickcore-6.q16-6 libmagickwand-6.q16-6 libmailtools-perl
#   libmediawiki-api-perl libmodule-implementation-perl libmodule-runtime-perl
#   libmro-compat-perl libnamespace-autoclean-perl libnamespace-clean-perl
#   libnet-dns-perl libnet-dns-sec-perl libnet-domain-tld-perl libnet-http-perl
#   libnet-ip-perl libnet-libidn-perl libnet-smtp-ssl-perl libnet-ssleay-perl
#   libotf0 libpackage-stash-perl libpackage-stash-xs-perl libpadwalker-perl
#   libparams-classify-perl libparams-util-perl libparams-validate-perl
#   libparams-validationcompiler-perl libperl4-corelibs-perl libreadonly-perl
#   libref-util-perl libref-util-xs-perl librole-tiny-perl libserf-1-1
#   libspecio-perl libsub-exporter-perl libsub-exporter-progressive-perl
#   libsub-identify-perl libsub-install-perl libsub-name-perl libsub-quote-perl
#   libsvn-perl libsvn1 libterm-readkey-perl libtry-tiny-perl
#   libtypes-serialiser-perl liburi-perl libutf8proc2 libvariable-magic-perl
#   libwww-perl libwww-robotrules-perl libxstring-perl libyaml-libyaml-perl
#   libyaml-perl m17n-db netbase perl-openssl-defaults poppler-data runit
#   ssl-cert
# 0 upgraded, 162 newly installed, 0 to remove and 21 not upgraded.
# Need to get 68.5 MB of archives.
# After this operation, 291 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/main amd64 install-info amd64 6.7.0.dfsg.2-5 [89.8 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/main amd64 libapr1 amd64 1.6.5-1ubuntu1 [91.4 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/main amd64 libaprutil1 amd64 1.6.1-4ubuntu2 [84.7 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/main amd64 libaprutil1-dbd-sqlite3 amd64 1.6.1-4ubuntu2 [10.5 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal/main amd64 libaprutil1-ldap amd64 1.6.1-4ubuntu2 [8,736 B]
# Get:6 http://archive.ubuntu.com/ubuntu focal/main amd64 liblua5.2-0 amd64 5.2.4-1.1build3 [106 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 apache2-bin amd64 2.4.41-4ubuntu3.13 [1,181 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 apache2-data all 2.4.41-4ubuntu3.13 [159 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 apache2-utils amd64 2.4.41-4ubuntu3.13 [84.1 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 apache2 amd64 2.4.41-4ubuntu3.13 [95.6 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal/main amd64 fonts-droid-fallback all 1:6.0.1r16-1.1 [1,805 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal/universe amd64 liblqr-1-0 amd64 0.4.2-2.1 [27.7 kB]
# Get:13 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 imagemagick-6-common all 8:6.9.10.23+dfsg-2.1ubuntu11.4 [60.9 kB]
# Get:14 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libmagickcore-6.q16-6 amd64 8:6.9.10.23+dfsg-2.1ubuntu11.4 [1,647 kB]
# Get:15 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libmagickwand-6.q16-6 amd64 8:6.9.10.23+dfsg-2.1ubuntu11.4 [303 kB]
# Get:16 http://archive.ubuntu.com/ubuntu focal/main amd64 poppler-data all 0.4.9-2 [1,475 kB]
# Get:17 http://archive.ubuntu.com/ubuntu focal/main amd64 netbase all 6.1 [13.1 kB]
# Get:18 http://archive.ubuntu.com/ubuntu focal/universe amd64 cvs amd64 2:1.12.13+real-27build1 [2,518 kB]
# Get:19 http://archive.ubuntu.com/ubuntu focal/universe amd64 cvsps amd64 2.1-8build2 [43.8 kB]
# Get:20 http://archive.ubuntu.com/ubuntu focal/universe amd64 dh-elpa-helper all 2.0.2 [7,496 B]
# Get:21 http://archive.ubuntu.com/ubuntu focal/universe amd64 elpa-let-alist all 1.0.6-1 [5,604 B]
# Get:22 http://archive.ubuntu.com/ubuntu focal/universe amd64 elpa-treepy all 0.1.1-2 [11.6 kB]
# Get:23 http://archive.ubuntu.com/ubuntu focal/universe amd64 elpa-ghub all 3.3.0-1 [54.6 kB]
# Get:24 http://archive.ubuntu.com/ubuntu focal/universe amd64 elpa-dash all 2.17.0+dfsg-1 [52.7 kB]
# Get:25 http://archive.ubuntu.com/ubuntu focal/universe amd64 elpa-with-editor all 2.9.1-1 [22.7 kB]
# Get:26 http://archive.ubuntu.com/ubuntu focal/universe amd64 elpa-git-commit all 2.90.1-2 [14.3 kB]
# Get:27 http://archive.ubuntu.com/ubuntu focal/universe amd64 elpa-magit-popup all 2.13.2-1 [25.7 kB]
# Get:28 http://archive.ubuntu.com/ubuntu focal/universe amd64 elpa-magit all 2.90.1-2 [394 kB]
# Get:29 http://archive.ubuntu.com/ubuntu focal/universe amd64 emacs-common all 1:26.3+1-1ubuntu2 [13.3 MB]
# Get:30 http://archive.ubuntu.com/ubuntu focal/universe amd64 emacs-bin-common amd64 1:26.3+1-1ubuntu2 [112 kB]
# Get:31 http://archive.ubuntu.com/ubuntu focal/main amd64 m17n-db all 1.8.0-3 [1,215 kB]
# Get:32 http://archive.ubuntu.com/ubuntu focal/main amd64 libotf0 amd64 0.9.13-7 [45.2 kB]
# Get:33 http://archive.ubuntu.com/ubuntu focal/main amd64 libm17n-0 amd64 1.8.0-2 [248 kB]
# Get:34 http://archive.ubuntu.com/ubuntu focal/universe amd64 emacs-gtk amd64 1:26.3+1-1ubuntu2 [3,588 kB]
# Get:35 http://archive.ubuntu.com/ubuntu focal/universe amd64 emacs all 1:26.3+1-1ubuntu2 [12.7 kB]
# Get:36 http://archive.ubuntu.com/ubuntu focal/universe amd64 emacs-el all 1:26.3+1-1ubuntu2 [15.9 MB]
# Get:37 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 fonts-noto-mono all 20200323-1build1~ubuntu20.04.1 [80.6 kB]
# Get:38 http://archive.ubuntu.com/ubuntu focal/main amd64 fonts-urw-base35 all 20170801.1-3 [6,333 kB]
# Get:39 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgs9-common all 9.50~dfsg-5ubuntu4.6 [681 kB]
# Get:40 http://archive.ubuntu.com/ubuntu focal/main amd64 libidn11 amd64 1.33-2.2ubuntu2 [46.2 kB]
# Get:41 http://archive.ubuntu.com/ubuntu focal/main amd64 libijs-0.35 amd64 0.35-15 [15.7 kB]
# Get:42 http://archive.ubuntu.com/ubuntu focal/main amd64 libjbig2dec0 amd64 0.18-1ubuntu1 [60.0 kB]
# Get:43 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgs9 amd64 9.50~dfsg-5ubuntu4.6 [2,173 kB]
# Get:44 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 ghostscript amd64 9.50~dfsg-5ubuntu4.6 [51.8 kB]
# Get:45 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 git-doc all 1:2.25.1-1ubuntu3.8 [994 kB]
# Get:46 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 git-el all 1:2.25.1-1ubuntu3.8 [8,816 B]
# Get:47 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libdbi-perl amd64 1.643-1ubuntu0.1 [730 kB]
# Get:48 http://archive.ubuntu.com/ubuntu focal/universe amd64 libdbd-sqlite3-perl amd64 1.64-1build1 [154 kB]
# Get:49 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 git-cvs all 1:2.25.1-1ubuntu3.8 [69.6 kB]
# Get:50 http://archive.ubuntu.com/ubuntu focal/main amd64 libjson-perl all 4.02000-2 [80.9 kB]
# Get:51 http://archive.ubuntu.com/ubuntu focal/main amd64 libencode-locale-perl all 1.05-1 [12.3 kB]
# Get:52 http://archive.ubuntu.com/ubuntu focal/main amd64 libhttp-date-perl all 6.05-1 [9,920 B]
# Get:53 http://archive.ubuntu.com/ubuntu focal/main amd64 libfile-listing-perl all 6.04-1 [9,774 B]
# Get:54 http://archive.ubuntu.com/ubuntu focal/main amd64 libhtml-tagset-perl all 3.20-4 [12.5 kB]
# Get:55 http://archive.ubuntu.com/ubuntu focal/main amd64 liburi-perl all 1.76-2 [77.5 kB]
# Get:56 http://archive.ubuntu.com/ubuntu focal/main amd64 libhtml-parser-perl amd64 3.72-5 [86.3 kB]
# Get:57 http://archive.ubuntu.com/ubuntu focal/main amd64 libhtml-tree-perl all 5.07-2 [200 kB]
# Get:58 http://archive.ubuntu.com/ubuntu focal/main amd64 libio-html-perl all 1.001-1 [14.9 kB]
# Get:59 http://archive.ubuntu.com/ubuntu focal/main amd64 liblwp-mediatypes-perl all 6.04-1 [19.5 kB]
# Get:60 http://archive.ubuntu.com/ubuntu focal/main amd64 libhttp-message-perl all 6.22-1 [76.1 kB]
# Get:61 http://archive.ubuntu.com/ubuntu focal/main amd64 libhttp-cookies-perl all 6.08-1 [18.3 kB]
# Get:62 http://archive.ubuntu.com/ubuntu focal/main amd64 libhttp-negotiate-perl all 6.01-1 [12.5 kB]
# Get:63 http://archive.ubuntu.com/ubuntu focal/main amd64 perl-openssl-defaults amd64 4 [7,192 B]
# Get:64 http://archive.ubuntu.com/ubuntu focal/main amd64 libnet-ssleay-perl amd64 1.88-2ubuntu1 [291 kB]
# Get:65 http://archive.ubuntu.com/ubuntu focal/main amd64 libio-socket-ssl-perl all 2.067-1 [176 kB]
# Get:66 http://archive.ubuntu.com/ubuntu focal/main amd64 libnet-http-perl all 6.19-1 [22.8 kB]
# Get:67 http://archive.ubuntu.com/ubuntu focal/main amd64 liblwp-protocol-https-perl all 6.07-2ubuntu2 [8,560 B]
# Get:68 http://archive.ubuntu.com/ubuntu focal/main amd64 libtry-tiny-perl all 0.30-1 [20.5 kB]
# Get:69 http://archive.ubuntu.com/ubuntu focal/main amd64 libwww-robotrules-perl all 6.02-1 [12.6 kB]
# Get:70 http://archive.ubuntu.com/ubuntu focal/main amd64 libwww-perl all 6.43-1 [140 kB]
# Get:71 http://archive.ubuntu.com/ubuntu focal/universe amd64 libmediawiki-api-perl all 0.41-2 [23.0 kB]
# Get:72 http://archive.ubuntu.com/ubuntu focal/universe amd64 libclass-inspector-perl all 1.36-1 [16.3 kB]
# Get:73 http://archive.ubuntu.com/ubuntu focal/universe amd64 libfile-sharedir-perl all 1.116-2 [14.7 kB]
# Get:74 http://archive.ubuntu.com/ubuntu focal/main amd64 libb-hooks-op-check-perl amd64 0.22-1build2 [10.2 kB]
# Get:75 http://archive.ubuntu.com/ubuntu focal/main amd64 libdynaloader-functions-perl all 0.003-1 [11.9 kB]
# Get:76 http://archive.ubuntu.com/ubuntu focal/main amd64 libdevel-callchecker-perl amd64 0.008-1ubuntu1 [14.5 kB]
# Get:77 http://archive.ubuntu.com/ubuntu focal/main amd64 libparams-classify-perl amd64 0.015-1build2 [21.1 kB]
# Get:78 http://archive.ubuntu.com/ubuntu focal/main amd64 libmodule-runtime-perl all 0.016-1 [16.2 kB]
# Get:79 http://archive.ubuntu.com/ubuntu focal/main amd64 libmodule-implementation-perl all 0.09-1 [12.2 kB]
# Get:80 http://archive.ubuntu.com/ubuntu focal/main amd64 libsub-exporter-progressive-perl all 0.001013-1 [6,784 B]
# Get:81 http://archive.ubuntu.com/ubuntu focal/main amd64 libvariable-magic-perl amd64 0.62-1build2 [34.4 kB]
# Get:82 http://archive.ubuntu.com/ubuntu focal/main amd64 libb-hooks-endofscope-perl all 0.24-1 [16.8 kB]
# Get:83 http://archive.ubuntu.com/ubuntu focal/main amd64 libpackage-stash-perl all 0.38-1 [19.1 kB]
# Get:84 http://archive.ubuntu.com/ubuntu focal/main amd64 libsub-identify-perl amd64 0.14-1build2 [10.7 kB]
# Get:85 http://archive.ubuntu.com/ubuntu focal/main amd64 libsub-name-perl amd64 0.26-1 [11.5 kB]
# Get:86 http://archive.ubuntu.com/ubuntu focal/main amd64 libnamespace-clean-perl all 0.27-1 [13.6 kB]
# Get:87 http://archive.ubuntu.com/ubuntu focal/universe amd64 libnamespace-autoclean-perl all 0.29-1 [12.5 kB]
# Get:88 http://archive.ubuntu.com/ubuntu focal/main amd64 libparams-util-perl amd64 1.07-3build5 [19.7 kB]
# Get:89 http://archive.ubuntu.com/ubuntu focal/main amd64 libsub-install-perl all 0.928-1 [10.5 kB]
# Get:90 http://archive.ubuntu.com/ubuntu focal/main amd64 libdata-optlist-perl all 0.110-1 [9,956 B]
# Get:91 http://archive.ubuntu.com/ubuntu focal/main amd64 libsub-exporter-perl all 0.987-1 [44.9 kB]
# Get:92 http://archive.ubuntu.com/ubuntu focal/universe amd64 libeval-closure-perl all 0.14-1 [10.3 kB]
# Get:93 http://archive.ubuntu.com/ubuntu focal/main amd64 libclass-data-inheritable-perl all 0.08-3 [8,084 B]
# Get:94 http://archive.ubuntu.com/ubuntu focal/main amd64 libdevel-stacktrace-perl all 2.0400-1 [22.7 kB]
# Get:95 http://archive.ubuntu.com/ubuntu focal/main amd64 libexception-class-perl all 1.44-1 [25.9 kB]
# Get:96 http://archive.ubuntu.com/ubuntu focal/universe amd64 libparams-validationcompiler-perl all 0.30-1 [28.9 kB]
# Get:97 http://archive.ubuntu.com/ubuntu focal/universe amd64 libalgorithm-c3-perl all 0.10-1 [11.3 kB]
# Get:98 http://archive.ubuntu.com/ubuntu focal/universe amd64 libclass-c3-perl all 0.34-1 [18.9 kB]
# Get:99 http://archive.ubuntu.com/ubuntu focal/universe amd64 libmro-compat-perl all 0.13-1 [11.2 kB]
# Get:100 http://archive.ubuntu.com/ubuntu focal/main amd64 libclass-method-modifiers-perl all 2.13-1 [16.2 kB]
# Get:101 http://archive.ubuntu.com/ubuntu focal/main amd64 librole-tiny-perl all 2.001004-1 [16.5 kB]
# Get:102 http://archive.ubuntu.com/ubuntu focal/main amd64 libsub-quote-perl all 2.006006-1 [19.5 kB]
# Get:103 http://archive.ubuntu.com/ubuntu focal/universe amd64 libxstring-perl amd64 0.002-2 [7,276 B]
# Get:104 http://archive.ubuntu.com/ubuntu focal/universe amd64 libspecio-perl all 0.45-1 [138 kB]
# Get:105 http://archive.ubuntu.com/ubuntu focal/universe amd64 libdatetime-locale-perl all 1:1.25-1 [2,357 kB]
# Get:106 http://archive.ubuntu.com/ubuntu focal/universe amd64 libclass-singleton-perl all 1.5-1 [13.0 kB]
# Get:107 http://archive.ubuntu.com/ubuntu focal/universe amd64 libdatetime-timezone-perl all 1:2.38-1+2019c [255 kB]
# Get:108 http://archive.ubuntu.com/ubuntu focal/universe amd64 libdatetime-perl amd64 2:1.51-1build1 [92.6 kB]
# Get:109 http://archive.ubuntu.com/ubuntu focal/universe amd64 libdatetime-format-strptime-perl all 1.7600-1 [27.7 kB]
# Get:110 http://archive.ubuntu.com/ubuntu focal/main amd64 libparams-validate-perl amd64 1.29-3 [52.7 kB]
# Get:111 http://archive.ubuntu.com/ubuntu focal/universe amd64 libdatetime-format-builder-perl all 0.8200-1 [62.4 kB]
# Get:112 http://archive.ubuntu.com/ubuntu focal/universe amd64 libdatetime-format-iso8601-perl all 0.08-2 [14.6 kB]
# Get:113 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 git-mediawiki all 1:2.25.1-1ubuntu3.8 [22.3 kB]
# Get:114 http://archive.ubuntu.com/ubuntu focal/universe amd64 libserf-1-1 amd64 1.3.9-8build1 [45.2 kB]
# Get:115 http://archive.ubuntu.com/ubuntu focal/universe amd64 libutf8proc2 amd64 2.5.0-1 [50.0 kB]
# Get:116 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libsvn1 amd64 1.13.0-3ubuntu0.2 [1,260 kB]
# Get:117 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libsvn-perl amd64 1.13.0-3ubuntu0.2 [937 kB]
# Get:118 http://archive.ubuntu.com/ubuntu focal/main amd64 libyaml-perl all 1.30-1 [58.2 kB]
# Get:119 http://archive.ubuntu.com/ubuntu focal/main amd64 libterm-readkey-perl amd64 2.38-1build1 [24.6 kB]
# Get:120 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 git-svn all 1:2.25.1-1ubuntu3.8 [81.1 kB]
# Get:121 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 git-email all 1:2.25.1-1ubuntu3.8 [31.7 kB]
# Get:122 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 git-gui all 1:2.25.1-1ubuntu3.8 [222 kB]
# Get:123 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 gitk all 1:2.25.1-1ubuntu3.8 [141 kB]
# Get:124 http://archive.ubuntu.com/ubuntu focal/main amd64 libcgi-pm-perl all 4.46-1 [186 kB]
# Get:125 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 gitweb all 1:2.25.1-1ubuntu3.8 [10.6 kB]
# Get:126 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 git-all all 1:2.25.1-1ubuntu3.8 [6,624 B]
# Get:127 http://archive.ubuntu.com/ubuntu focal/universe amd64 runit amd64 2.1.2-9.2ubuntu1 [95.9 kB]
# Get:128 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 git-daemon-run all 1:2.25.1-1ubuntu3.8 [8,100 B]
# Get:129 http://archive.ubuntu.com/ubuntu focal/universe amd64 gsfonts all 1:8.11+urwcyr1.0.7~pre44-4.4 [3,120 kB]
# Get:130 http://archive.ubuntu.com/ubuntu focal/main amd64 libfcgi-perl amd64 0.79-1 [33.1 kB]
# Get:131 http://archive.ubuntu.com/ubuntu focal/main amd64 libcgi-fast-perl all 1:2.15-1 [10.5 kB]
# Get:132 http://archive.ubuntu.com/ubuntu focal/universe amd64 libclass-c3-xs-perl amd64 0.14-1build5 [15.5 kB]
# Get:133 http://archive.ubuntu.com/ubuntu focal/main amd64 libclass-xsaccessor-perl amd64 1.19-3build3 [33.6 kB]
# Get:134 http://archive.ubuntu.com/ubuntu focal/main amd64 libcommon-sense-perl amd64 3.74-2build6 [20.1 kB]
# Get:135 http://archive.ubuntu.com/ubuntu focal/main amd64 libdata-dump-perl all 1.23-1 [27.0 kB]
# Get:136 http://archive.ubuntu.com/ubuntu focal/universe amd64 libpadwalker-perl amd64 2.3-1build2 [15.2 kB]
# Get:137 http://archive.ubuntu.com/ubuntu focal/universe amd64 libdevel-caller-perl amd64 2.06-2build2 [10.6 kB]
# Get:138 http://archive.ubuntu.com/ubuntu focal/universe amd64 libdevel-lexalias-perl amd64 0.05-2build2 [8,788 B]
# Get:139 http://archive.ubuntu.com/ubuntu focal/main amd64 libdigest-bubblebabble-perl all 0.02-2 [7,908 B]
# Get:140 http://archive.ubuntu.com/ubuntu focal/main amd64 libdigest-hmac-perl all 1.03+dfsg-2 [10.3 kB]
# Get:141 http://archive.ubuntu.com/ubuntu focal/main amd64 libnet-smtp-ssl-perl all 1.04-1 [5,948 B]
# Get:142 http://archive.ubuntu.com/ubuntu focal/main amd64 libmailtools-perl all 2.21-1 [80.7 kB]
# Get:143 http://archive.ubuntu.com/ubuntu focal/main amd64 libnet-ip-perl all 1.26-2 [27.4 kB]
# Get:144 http://archive.ubuntu.com/ubuntu focal/main amd64 libnet-dns-perl all 1.22-1 [336 kB]
# Get:145 http://archive.ubuntu.com/ubuntu focal/main amd64 libnet-domain-tld-perl all 1.75-1 [29.1 kB]
# Get:146 http://archive.ubuntu.com/ubuntu focal/main amd64 libemail-valid-perl all 1.202-1 [16.3 kB]
# Get:147 http://archive.ubuntu.com/ubuntu focal/main amd64 libfont-afm-perl all 1.20-2 [13.2 kB]
# Get:148 http://archive.ubuntu.com/ubuntu focal/main amd64 libhtml-form-perl all 6.07-1 [22.2 kB]
# Get:149 http://archive.ubuntu.com/ubuntu focal/main amd64 libhtml-format-perl all 2.12-1 [41.3 kB]
# Get:150 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libhttp-daemon-perl all 6.06-1ubuntu0.1 [22.0 kB]
# Get:151 http://archive.ubuntu.com/ubuntu focal/main amd64 libtypes-serialiser-perl all 1.0-1 [12.1 kB]
# Get:152 http://archive.ubuntu.com/ubuntu focal/main amd64 libjson-xs-perl amd64 4.020-1build1 [83.7 kB]
# Get:153 http://archive.ubuntu.com/ubuntu focal/main amd64 libnet-dns-sec-perl amd64 1.15-1 [44.6 kB]
# Get:154 http://archive.ubuntu.com/ubuntu focal/main amd64 libnet-libidn-perl amd64 0.12.ds-3build2 [17.3 kB]
# Get:155 http://archive.ubuntu.com/ubuntu focal/main amd64 libpackage-stash-xs-perl amd64 0.29-1build1 [18.4 kB]
# Get:156 http://archive.ubuntu.com/ubuntu focal/main amd64 libperl4-corelibs-perl all 0.004-2 [37.4 kB]
# Get:157 http://archive.ubuntu.com/ubuntu focal/main amd64 libreadonly-perl all 2.050-2 [19.9 kB]
# Get:158 http://archive.ubuntu.com/ubuntu focal/main amd64 libref-util-perl all 0.204-1 [15.0 kB]
# Get:159 http://archive.ubuntu.com/ubuntu focal/main amd64 libref-util-xs-perl amd64 0.117-1build2 [12.0 kB]
# Get:160 http://archive.ubuntu.com/ubuntu focal/main amd64 libyaml-libyaml-perl amd64 0.81+repack-1 [28.5 kB]
# Get:161 http://archive.ubuntu.com/ubuntu focal/main amd64 ssl-cert all 1.0.39 [17.0 kB]
# Get:162 http://archive.ubuntu.com/ubuntu focal/main amd64 libauthen-sasl-perl all 2.1600-1 [48.7 kB]
# Fetched 68.5 MB in 11s (6,525 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 162.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package install-info.
# (Reading database ... 128097 files and directories currently installed.)
# Preparing to unpack .../install-info_6.7.0.dfsg.2-5_amd64.deb ...
# Unpacking install-info (6.7.0.dfsg.2-5) ...
# Setting up install-info (6.7.0.dfsg.2-5) ...
# Selecting previously unselected package libapr1:amd64.
# (Reading database ... 128110 files and directories currently installed.)
# Preparing to unpack .../000-libapr1_1.6.5-1ubuntu1_amd64.deb ...
# Unpacking libapr1:amd64 (1.6.5-1ubuntu1) ...
# Selecting previously unselected package libaprutil1:amd64.
# Preparing to unpack .../001-libaprutil1_1.6.1-4ubuntu2_amd64.deb ...
# Unpacking libaprutil1:amd64 (1.6.1-4ubuntu2) ...
# Selecting previously unselected package libaprutil1-dbd-sqlite3:amd64.
# Preparing to unpack .../002-libaprutil1-dbd-sqlite3_1.6.1-4ubuntu2_amd64.deb ...
# Unpacking libaprutil1-dbd-sqlite3:amd64 (1.6.1-4ubuntu2) ...
# Selecting previously unselected package libaprutil1-ldap:amd64.
# Preparing to unpack .../003-libaprutil1-ldap_1.6.1-4ubuntu2_amd64.deb ...
# Unpacking libaprutil1-ldap:amd64 (1.6.1-4ubuntu2) ...
# Selecting previously unselected package liblua5.2-0:amd64.
# Preparing to unpack .../004-liblua5.2-0_5.2.4-1.1build3_amd64.deb ...
# Unpacking liblua5.2-0:amd64 (5.2.4-1.1build3) ...
# Selecting previously unselected package apache2-bin.
# Preparing to unpack .../005-apache2-bin_2.4.41-4ubuntu3.13_amd64.deb ...
# Unpacking apache2-bin (2.4.41-4ubuntu3.13) ...
# Selecting previously unselected package apache2-data.
# Preparing to unpack .../006-apache2-data_2.4.41-4ubuntu3.13_all.deb ...
# Unpacking apache2-data (2.4.41-4ubuntu3.13) ...
# Selecting previously unselected package apache2-utils.
# Preparing to unpack .../007-apache2-utils_2.4.41-4ubuntu3.13_amd64.deb ...
# Unpacking apache2-utils (2.4.41-4ubuntu3.13) ...
# Selecting previously unselected package apache2.
# Preparing to unpack .../008-apache2_2.4.41-4ubuntu3.13_amd64.deb ...
# Unpacking apache2 (2.4.41-4ubuntu3.13) ...
# Selecting previously unselected package fonts-droid-fallback.
# Preparing to unpack .../009-fonts-droid-fallback_1%3a6.0.1r16-1.1_all.deb ...
# Unpacking fonts-droid-fallback (1:6.0.1r16-1.1) ...
# Selecting previously unselected package liblqr-1-0:amd64.
# Preparing to unpack .../010-liblqr-1-0_0.4.2-2.1_amd64.deb ...
# Unpacking liblqr-1-0:amd64 (0.4.2-2.1) ...
# Selecting previously unselected package imagemagick-6-common.
# Preparing to unpack .../011-imagemagick-6-common_8%3a6.9.10.23+dfsg-2.1ubuntu11.4_all.deb ...
# Unpacking imagemagick-6-common (8:6.9.10.23+dfsg-2.1ubuntu11.4) ...
# Selecting previously unselected package libmagickcore-6.q16-6:amd64.
# Preparing to unpack .../012-libmagickcore-6.q16-6_8%3a6.9.10.23+dfsg-2.1ubuntu11.4_amd64.deb ...
# Unpacking libmagickcore-6.q16-6:amd64 (8:6.9.10.23+dfsg-2.1ubuntu11.4) ...
# Selecting previously unselected package libmagickwand-6.q16-6:amd64.
# Preparing to unpack .../013-libmagickwand-6.q16-6_8%3a6.9.10.23+dfsg-2.1ubuntu11.4_amd64.deb ...
# Unpacking libmagickwand-6.q16-6:amd64 (8:6.9.10.23+dfsg-2.1ubuntu11.4) ...
# Selecting previously unselected package poppler-data.
# Preparing to unpack .../014-poppler-data_0.4.9-2_all.deb ...
# Unpacking poppler-data (0.4.9-2) ...
# Selecting previously unselected package netbase.
# Preparing to unpack .../015-netbase_6.1_all.deb ...
# Unpacking netbase (6.1) ...
# Selecting previously unselected package cvs.
# Preparing to unpack .../016-cvs_2%3a1.12.13+real-27build1_amd64.deb ...
# Unpacking cvs (2:1.12.13+real-27build1) ...
# Selecting previously unselected package cvsps.
# Preparing to unpack .../017-cvsps_2.1-8build2_amd64.deb ...
# Unpacking cvsps (2.1-8build2) ...
# Selecting previously unselected package dh-elpa-helper.
# Preparing to unpack .../018-dh-elpa-helper_2.0.2_all.deb ...
# Unpacking dh-elpa-helper (2.0.2) ...
# Selecting previously unselected package elpa-let-alist.
# Preparing to unpack .../019-elpa-let-alist_1.0.6-1_all.deb ...
# Unpacking elpa-let-alist (1.0.6-1) ...
# Selecting previously unselected package elpa-treepy.
# Preparing to unpack .../020-elpa-treepy_0.1.1-2_all.deb ...
# Unpacking elpa-treepy (0.1.1-2) ...
# Selecting previously unselected package elpa-ghub.
# Preparing to unpack .../021-elpa-ghub_3.3.0-1_all.deb ...
# Unpacking elpa-ghub (3.3.0-1) ...
# Selecting previously unselected package elpa-dash.
# Preparing to unpack .../022-elpa-dash_2.17.0+dfsg-1_all.deb ...
# Unpacking elpa-dash (2.17.0+dfsg-1) ...
# Selecting previously unselected package elpa-with-editor.
# Preparing to unpack .../023-elpa-with-editor_2.9.1-1_all.deb ...
# Unpacking elpa-with-editor (2.9.1-1) ...
# Selecting previously unselected package elpa-git-commit.
# Preparing to unpack .../024-elpa-git-commit_2.90.1-2_all.deb ...
# Unpacking elpa-git-commit (2.90.1-2) ...
# Selecting previously unselected package elpa-magit-popup.
# Preparing to unpack .../025-elpa-magit-popup_2.13.2-1_all.deb ...
# Unpacking elpa-magit-popup (2.13.2-1) ...
# Selecting previously unselected package elpa-magit.
# Preparing to unpack .../026-elpa-magit_2.90.1-2_all.deb ...
# Unpacking elpa-magit (2.90.1-2) ...
# Selecting previously unselected package emacs-common.
# Preparing to unpack .../027-emacs-common_1%3a26.3+1-1ubuntu2_all.deb ...
# Unpacking emacs-common (1:26.3+1-1ubuntu2) ...
# Selecting previously unselected package emacs-bin-common.
# Preparing to unpack .../028-emacs-bin-common_1%3a26.3+1-1ubuntu2_amd64.deb ...
# Unpacking emacs-bin-common (1:26.3+1-1ubuntu2) ...
# Selecting previously unselected package m17n-db.
# Preparing to unpack .../029-m17n-db_1.8.0-3_all.deb ...
# Unpacking m17n-db (1.8.0-3) ...
# Selecting previously unselected package libotf0:amd64.
# Preparing to unpack .../030-libotf0_0.9.13-7_amd64.deb ...
# Unpacking libotf0:amd64 (0.9.13-7) ...
# Selecting previously unselected package libm17n-0:amd64.
# Preparing to unpack .../031-libm17n-0_1.8.0-2_amd64.deb ...
# Unpacking libm17n-0:amd64 (1.8.0-2) ...
# Selecting previously unselected package emacs-gtk.
# Preparing to unpack .../032-emacs-gtk_1%3a26.3+1-1ubuntu2_amd64.deb ...
# Unpacking emacs-gtk (1:26.3+1-1ubuntu2) ...
# Selecting previously unselected package emacs.
# Preparing to unpack .../033-emacs_1%3a26.3+1-1ubuntu2_all.deb ...
# Unpacking emacs (1:26.3+1-1ubuntu2) ...
# Selecting previously unselected package emacs-el.
# Preparing to unpack .../034-emacs-el_1%3a26.3+1-1ubuntu2_all.deb ...
# Unpacking emacs-el (1:26.3+1-1ubuntu2) ...
# Selecting previously unselected package fonts-noto-mono.
# Preparing to unpack .../035-fonts-noto-mono_20200323-1build1~ubuntu20.04.1_all.deb ...
# Unpacking fonts-noto-mono (20200323-1build1~ubuntu20.04.1) ...
# Selecting previously unselected package fonts-urw-base35.
# Preparing to unpack .../036-fonts-urw-base35_20170801.1-3_all.deb ...
# Unpacking fonts-urw-base35 (20170801.1-3) ...
# Selecting previously unselected package libgs9-common.
# Preparing to unpack .../037-libgs9-common_9.50~dfsg-5ubuntu4.6_all.deb ...
# Unpacking libgs9-common (9.50~dfsg-5ubuntu4.6) ...
# Selecting previously unselected package libidn11:amd64.
# Preparing to unpack .../038-libidn11_1.33-2.2ubuntu2_amd64.deb ...
# Unpacking libidn11:amd64 (1.33-2.2ubuntu2) ...
# Selecting previously unselected package libijs-0.35:amd64.
# Preparing to unpack .../039-libijs-0.35_0.35-15_amd64.deb ...
# Unpacking libijs-0.35:amd64 (0.35-15) ...
# Selecting previously unselected package libjbig2dec0:amd64.
# Preparing to unpack .../040-libjbig2dec0_0.18-1ubuntu1_amd64.deb ...
# Unpacking libjbig2dec0:amd64 (0.18-1ubuntu1) ...
# Selecting previously unselected package libgs9:amd64.
# Preparing to unpack .../041-libgs9_9.50~dfsg-5ubuntu4.6_amd64.deb ...
# Unpacking libgs9:amd64 (9.50~dfsg-5ubuntu4.6) ...
# Selecting previously unselected package ghostscript.
# Preparing to unpack .../042-ghostscript_9.50~dfsg-5ubuntu4.6_amd64.deb ...
# Unpacking ghostscript (9.50~dfsg-5ubuntu4.6) ...
# Selecting previously unselected package git-doc.
# Preparing to unpack .../043-git-doc_1%3a2.25.1-1ubuntu3.8_all.deb ...
# Unpacking git-doc (1:2.25.1-1ubuntu3.8) ...
# Selecting previously unselected package git-el.
# Preparing to unpack .../044-git-el_1%3a2.25.1-1ubuntu3.8_all.deb ...
# Unpacking git-el (1:2.25.1-1ubuntu3.8) ...
# Selecting previously unselected package libdbi-perl:amd64.
# Preparing to unpack .../045-libdbi-perl_1.643-1ubuntu0.1_amd64.deb ...
# Unpacking libdbi-perl:amd64 (1.643-1ubuntu0.1) ...
# Selecting previously unselected package libdbd-sqlite3-perl:amd64.
# Preparing to unpack .../046-libdbd-sqlite3-perl_1.64-1build1_amd64.deb ...
# Unpacking libdbd-sqlite3-perl:amd64 (1.64-1build1) ...
# Selecting previously unselected package git-cvs.
# Preparing to unpack .../047-git-cvs_1%3a2.25.1-1ubuntu3.8_all.deb ...
# Unpacking git-cvs (1:2.25.1-1ubuntu3.8) ...
# Selecting previously unselected package libjson-perl.
# Preparing to unpack .../048-libjson-perl_4.02000-2_all.deb ...
# Unpacking libjson-perl (4.02000-2) ...
# Selecting previously unselected package libencode-locale-perl.
# Preparing to unpack .../049-libencode-locale-perl_1.05-1_all.deb ...
# Unpacking libencode-locale-perl (1.05-1) ...
# Selecting previously unselected package libhttp-date-perl.
# Preparing to unpack .../050-libhttp-date-perl_6.05-1_all.deb ...
# Unpacking libhttp-date-perl (6.05-1) ...
# Selecting previously unselected package libfile-listing-perl.
# Preparing to unpack .../051-libfile-listing-perl_6.04-1_all.deb ...
# Unpacking libfile-listing-perl (6.04-1) ...
# Selecting previously unselected package libhtml-tagset-perl.
# Preparing to unpack .../052-libhtml-tagset-perl_3.20-4_all.deb ...
# Unpacking libhtml-tagset-perl (3.20-4) ...
# Selecting previously unselected package liburi-perl.
# Preparing to unpack .../053-liburi-perl_1.76-2_all.deb ...
# Unpacking liburi-perl (1.76-2) ...
# Selecting previously unselected package libhtml-parser-perl.
# Preparing to unpack .../054-libhtml-parser-perl_3.72-5_amd64.deb ...
# Unpacking libhtml-parser-perl (3.72-5) ...
# Selecting previously unselected package libhtml-tree-perl.
# Preparing to unpack .../055-libhtml-tree-perl_5.07-2_all.deb ...
# Unpacking libhtml-tree-perl (5.07-2) ...
# Selecting previously unselected package libio-html-perl.
# Preparing to unpack .../056-libio-html-perl_1.001-1_all.deb ...
# Unpacking libio-html-perl (1.001-1) ...
# Selecting previously unselected package liblwp-mediatypes-perl.
# Preparing to unpack .../057-liblwp-mediatypes-perl_6.04-1_all.deb ...
# Unpacking liblwp-mediatypes-perl (6.04-1) ...
# Selecting previously unselected package libhttp-message-perl.
# Preparing to unpack .../058-libhttp-message-perl_6.22-1_all.deb ...
# Unpacking libhttp-message-perl (6.22-1) ...
# Selecting previously unselected package libhttp-cookies-perl.
# Preparing to unpack .../059-libhttp-cookies-perl_6.08-1_all.deb ...
# Unpacking libhttp-cookies-perl (6.08-1) ...
# Selecting previously unselected package libhttp-negotiate-perl.
# Preparing to unpack .../060-libhttp-negotiate-perl_6.01-1_all.deb ...
# Unpacking libhttp-negotiate-perl (6.01-1) ...
# Selecting previously unselected package perl-openssl-defaults:amd64.
# Preparing to unpack .../061-perl-openssl-defaults_4_amd64.deb ...
# Unpacking perl-openssl-defaults:amd64 (4) ...
# Selecting previously unselected package libnet-ssleay-perl.
# Preparing to unpack .../062-libnet-ssleay-perl_1.88-2ubuntu1_amd64.deb ...
# Unpacking libnet-ssleay-perl (1.88-2ubuntu1) ...
# Selecting previously unselected package libio-socket-ssl-perl.
# Preparing to unpack .../063-libio-socket-ssl-perl_2.067-1_all.deb ...
# Unpacking libio-socket-ssl-perl (2.067-1) ...
# Selecting previously unselected package libnet-http-perl.
# Preparing to unpack .../064-libnet-http-perl_6.19-1_all.deb ...
# Unpacking libnet-http-perl (6.19-1) ...
# Selecting previously unselected package liblwp-protocol-https-perl.
# Preparing to unpack .../065-liblwp-protocol-https-perl_6.07-2ubuntu2_all.deb ...
# Unpacking liblwp-protocol-https-perl (6.07-2ubuntu2) ...
# Selecting previously unselected package libtry-tiny-perl.
# Preparing to unpack .../066-libtry-tiny-perl_0.30-1_all.deb ...
# Unpacking libtry-tiny-perl (0.30-1) ...
# Selecting previously unselected package libwww-robotrules-perl.
# Preparing to unpack .../067-libwww-robotrules-perl_6.02-1_all.deb ...
# Unpacking libwww-robotrules-perl (6.02-1) ...
# Selecting previously unselected package libwww-perl.
# Preparing to unpack .../068-libwww-perl_6.43-1_all.deb ...
# Unpacking libwww-perl (6.43-1) ...
# Selecting previously unselected package libmediawiki-api-perl.
# Preparing to unpack .../069-libmediawiki-api-perl_0.41-2_all.deb ...
# Unpacking libmediawiki-api-perl (0.41-2) ...
# Selecting previously unselected package libclass-inspector-perl.
# Preparing to unpack .../070-libclass-inspector-perl_1.36-1_all.deb ...
# Unpacking libclass-inspector-perl (1.36-1) ...
# Selecting previously unselected package libfile-sharedir-perl.
# Preparing to unpack .../071-libfile-sharedir-perl_1.116-2_all.deb ...
# Unpacking libfile-sharedir-perl (1.116-2) ...
# Selecting previously unselected package libb-hooks-op-check-perl.
# Preparing to unpack .../072-libb-hooks-op-check-perl_0.22-1build2_amd64.deb ...
# Unpacking libb-hooks-op-check-perl (0.22-1build2) ...
# Selecting previously unselected package libdynaloader-functions-perl.
# Preparing to unpack .../073-libdynaloader-functions-perl_0.003-1_all.deb ...
# Unpacking libdynaloader-functions-perl (0.003-1) ...
# Selecting previously unselected package libdevel-callchecker-perl.
# Preparing to unpack .../074-libdevel-callchecker-perl_0.008-1ubuntu1_amd64.deb ...
# Unpacking libdevel-callchecker-perl (0.008-1ubuntu1) ...
# Selecting previously unselected package libparams-classify-perl.
# Preparing to unpack .../075-libparams-classify-perl_0.015-1build2_amd64.deb ...
# Unpacking libparams-classify-perl (0.015-1build2) ...
# Selecting previously unselected package libmodule-runtime-perl.
# Preparing to unpack .../076-libmodule-runtime-perl_0.016-1_all.deb ...
# Unpacking libmodule-runtime-perl (0.016-1) ...
# Selecting previously unselected package libmodule-implementation-perl.
# Preparing to unpack .../077-libmodule-implementation-perl_0.09-1_all.deb ...
# Unpacking libmodule-implementation-perl (0.09-1) ...
# Selecting previously unselected package libsub-exporter-progressive-perl.
# Preparing to unpack .../078-libsub-exporter-progressive-perl_0.001013-1_all.deb ...
# Unpacking libsub-exporter-progressive-perl (0.001013-1) ...
# Selecting previously unselected package libvariable-magic-perl.
# Preparing to unpack .../079-libvariable-magic-perl_0.62-1build2_amd64.deb ...
# Unpacking libvariable-magic-perl (0.62-1build2) ...
# Selecting previously unselected package libb-hooks-endofscope-perl.
# Preparing to unpack .../080-libb-hooks-endofscope-perl_0.24-1_all.deb ...
# Unpacking libb-hooks-endofscope-perl (0.24-1) ...
# Selecting previously unselected package libpackage-stash-perl.
# Preparing to unpack .../081-libpackage-stash-perl_0.38-1_all.deb ...
# Unpacking libpackage-stash-perl (0.38-1) ...
# Selecting previously unselected package libsub-identify-perl.
# Preparing to unpack .../082-libsub-identify-perl_0.14-1build2_amd64.deb ...
# Unpacking libsub-identify-perl (0.14-1build2) ...
# Selecting previously unselected package libsub-name-perl.
# Preparing to unpack .../083-libsub-name-perl_0.26-1_amd64.deb ...
# Unpacking libsub-name-perl (0.26-1) ...
# Selecting previously unselected package libnamespace-clean-perl.
# Preparing to unpack .../084-libnamespace-clean-perl_0.27-1_all.deb ...
# Unpacking libnamespace-clean-perl (0.27-1) ...
# Selecting previously unselected package libnamespace-autoclean-perl.
# Preparing to unpack .../085-libnamespace-autoclean-perl_0.29-1_all.deb ...
# Unpacking libnamespace-autoclean-perl (0.29-1) ...
# Selecting previously unselected package libparams-util-perl.
# Preparing to unpack .../086-libparams-util-perl_1.07-3build5_amd64.deb ...
# Unpacking libparams-util-perl (1.07-3build5) ...
# Selecting previously unselected package libsub-install-perl.
# Preparing to unpack .../087-libsub-install-perl_0.928-1_all.deb ...
# Unpacking libsub-install-perl (0.928-1) ...
# Selecting previously unselected package libdata-optlist-perl.
# Preparing to unpack .../088-libdata-optlist-perl_0.110-1_all.deb ...
# Unpacking libdata-optlist-perl (0.110-1) ...
# Selecting previously unselected package libsub-exporter-perl.
# Preparing to unpack .../089-libsub-exporter-perl_0.987-1_all.deb ...
# Unpacking libsub-exporter-perl (0.987-1) ...
# Selecting previously unselected package libeval-closure-perl.
# Preparing to unpack .../090-libeval-closure-perl_0.14-1_all.deb ...
# Unpacking libeval-closure-perl (0.14-1) ...
# Selecting previously unselected package libclass-data-inheritable-perl.
# Preparing to unpack .../091-libclass-data-inheritable-perl_0.08-3_all.deb ...
# Unpacking libclass-data-inheritable-perl (0.08-3) ...
# Selecting previously unselected package libdevel-stacktrace-perl.
# Preparing to unpack .../092-libdevel-stacktrace-perl_2.0400-1_all.deb ...
# Unpacking libdevel-stacktrace-perl (2.0400-1) ...
# Selecting previously unselected package libexception-class-perl.
# Preparing to unpack .../093-libexception-class-perl_1.44-1_all.deb ...
# Unpacking libexception-class-perl (1.44-1) ...
# Selecting previously unselected package libparams-validationcompiler-perl.
# Preparing to unpack .../094-libparams-validationcompiler-perl_0.30-1_all.deb ...
# Unpacking libparams-validationcompiler-perl (0.30-1) ...
# Selecting previously unselected package libalgorithm-c3-perl.
# Preparing to unpack .../095-libalgorithm-c3-perl_0.10-1_all.deb ...
# Unpacking libalgorithm-c3-perl (0.10-1) ...
# Selecting previously unselected package libclass-c3-perl.
# Preparing to unpack .../096-libclass-c3-perl_0.34-1_all.deb ...
# Unpacking libclass-c3-perl (0.34-1) ...
# Selecting previously unselected package libmro-compat-perl.
# Preparing to unpack .../097-libmro-compat-perl_0.13-1_all.deb ...
# Unpacking libmro-compat-perl (0.13-1) ...
# Selecting previously unselected package libclass-method-modifiers-perl.
# Preparing to unpack .../098-libclass-method-modifiers-perl_2.13-1_all.deb ...
# Unpacking libclass-method-modifiers-perl (2.13-1) ...
# Selecting previously unselected package librole-tiny-perl.
# Preparing to unpack .../099-librole-tiny-perl_2.001004-1_all.deb ...
# Unpacking librole-tiny-perl (2.001004-1) ...
# Selecting previously unselected package libsub-quote-perl.
# Preparing to unpack .../100-libsub-quote-perl_2.006006-1_all.deb ...
# Unpacking libsub-quote-perl (2.006006-1) ...
# Selecting previously unselected package libxstring-perl.
# Preparing to unpack .../101-libxstring-perl_0.002-2_amd64.deb ...
# Unpacking libxstring-perl (0.002-2) ...
# Selecting previously unselected package libspecio-perl.
# Preparing to unpack .../102-libspecio-perl_0.45-1_all.deb ...
# Unpacking libspecio-perl (0.45-1) ...
# Selecting previously unselected package libdatetime-locale-perl.
# Preparing to unpack .../103-libdatetime-locale-perl_1%3a1.25-1_all.deb ...
# Unpacking libdatetime-locale-perl (1:1.25-1) ...
# Selecting previously unselected package libclass-singleton-perl.
# Preparing to unpack .../104-libclass-singleton-perl_1.5-1_all.deb ...
# Unpacking libclass-singleton-perl (1.5-1) ...
# Selecting previously unselected package libdatetime-timezone-perl.
# Preparing to unpack .../105-libdatetime-timezone-perl_1%3a2.38-1+2019c_all.deb ...
# Unpacking libdatetime-timezone-perl (1:2.38-1+2019c) ...
# Selecting previously unselected package libdatetime-perl:amd64.
# Preparing to unpack .../106-libdatetime-perl_2%3a1.51-1build1_amd64.deb ...
# Unpacking libdatetime-perl:amd64 (2:1.51-1build1) ...
# Selecting previously unselected package libdatetime-format-strptime-perl.
# Preparing to unpack .../107-libdatetime-format-strptime-perl_1.7600-1_all.deb ...
# Unpacking libdatetime-format-strptime-perl (1.7600-1) ...
# Selecting previously unselected package libparams-validate-perl.
# Preparing to unpack .../108-libparams-validate-perl_1.29-3_amd64.deb ...
# Unpacking libparams-validate-perl (1.29-3) ...
# Selecting previously unselected package libdatetime-format-builder-perl.
# Preparing to unpack .../109-libdatetime-format-builder-perl_0.8200-1_all.deb ...
# Unpacking libdatetime-format-builder-perl (0.8200-1) ...
# Selecting previously unselected package libdatetime-format-iso8601-perl.
# Preparing to unpack .../110-libdatetime-format-iso8601-perl_0.08-2_all.deb ...
# Unpacking libdatetime-format-iso8601-perl (0.08-2) ...
# Selecting previously unselected package git-mediawiki.
# Preparing to unpack .../111-git-mediawiki_1%3a2.25.1-1ubuntu3.8_all.deb ...
# Unpacking git-mediawiki (1:2.25.1-1ubuntu3.8) ...
# Selecting previously unselected package libserf-1-1:amd64.
# Preparing to unpack .../112-libserf-1-1_1.3.9-8build1_amd64.deb ...
# Unpacking libserf-1-1:amd64 (1.3.9-8build1) ...
# Selecting previously unselected package libutf8proc2:amd64.
# Preparing to unpack .../113-libutf8proc2_2.5.0-1_amd64.deb ...
# Unpacking libutf8proc2:amd64 (2.5.0-1) ...
# Selecting previously unselected package libsvn1:amd64.
# Preparing to unpack .../114-libsvn1_1.13.0-3ubuntu0.2_amd64.deb ...
# Unpacking libsvn1:amd64 (1.13.0-3ubuntu0.2) ...
# Selecting previously unselected package libsvn-perl:amd64.
# Preparing to unpack .../115-libsvn-perl_1.13.0-3ubuntu0.2_amd64.deb ...
# Unpacking libsvn-perl:amd64 (1.13.0-3ubuntu0.2) ...
# Selecting previously unselected package libyaml-perl.
# Preparing to unpack .../116-libyaml-perl_1.30-1_all.deb ...
# Unpacking libyaml-perl (1.30-1) ...
# Selecting previously unselected package libterm-readkey-perl.
# Preparing to unpack .../117-libterm-readkey-perl_2.38-1build1_amd64.deb ...
# Unpacking libterm-readkey-perl (2.38-1build1) ...
# Selecting previously unselected package git-svn.
# Preparing to unpack .../118-git-svn_1%3a2.25.1-1ubuntu3.8_all.deb ...
# Unpacking git-svn (1:2.25.1-1ubuntu3.8) ...
# Selecting previously unselected package git-email.
# Preparing to unpack .../119-git-email_1%3a2.25.1-1ubuntu3.8_all.deb ...
# Unpacking git-email (1:2.25.1-1ubuntu3.8) ...
# Selecting previously unselected package git-gui.
# Preparing to unpack .../120-git-gui_1%3a2.25.1-1ubuntu3.8_all.deb ...
# Unpacking git-gui (1:2.25.1-1ubuntu3.8) ...
# Selecting previously unselected package gitk.
# Preparing to unpack .../121-gitk_1%3a2.25.1-1ubuntu3.8_all.deb ...
# Unpacking gitk (1:2.25.1-1ubuntu3.8) ...
# Selecting previously unselected package libcgi-pm-perl.
# Preparing to unpack .../122-libcgi-pm-perl_4.46-1_all.deb ...
# Unpacking libcgi-pm-perl (4.46-1) ...
# Selecting previously unselected package gitweb.
# Preparing to unpack .../123-gitweb_1%3a2.25.1-1ubuntu3.8_all.deb ...
# Unpacking gitweb (1:2.25.1-1ubuntu3.8) ...
# Selecting previously unselected package git-all.
# Preparing to unpack .../124-git-all_1%3a2.25.1-1ubuntu3.8_all.deb ...
# Unpacking git-all (1:2.25.1-1ubuntu3.8) ...
# Selecting previously unselected package runit.
# Preparing to unpack .../125-runit_2.1.2-9.2ubuntu1_amd64.deb ...
# + [ install = upgrade ]
# Unpacking runit (2.1.2-9.2ubuntu1) ...
# Selecting previously unselected package git-daemon-run.
# Preparing to unpack .../126-git-daemon-run_1%3a2.25.1-1ubuntu3.8_all.deb ...
# Unpacking git-daemon-run (1:2.25.1-1ubuntu3.8) ...
# Selecting previously unselected package gsfonts.
# Preparing to unpack .../127-gsfonts_1%3a8.11+urwcyr1.0.7~pre44-4.4_all.deb ...
# Unpacking gsfonts (1:8.11+urwcyr1.0.7~pre44-4.4) ...
# Selecting previously unselected package libfcgi-perl.
# Preparing to unpack .../128-libfcgi-perl_0.79-1_amd64.deb ...
# Unpacking libfcgi-perl (0.79-1) ...
# Selecting previously unselected package libcgi-fast-perl.
# Preparing to unpack .../129-libcgi-fast-perl_1%3a2.15-1_all.deb ...
# Unpacking libcgi-fast-perl (1:2.15-1) ...
# Selecting previously unselected package libclass-c3-xs-perl.
# Preparing to unpack .../130-libclass-c3-xs-perl_0.14-1build5_amd64.deb ...
# Unpacking libclass-c3-xs-perl (0.14-1build5) ...
# Selecting previously unselected package libclass-xsaccessor-perl.
# ...
# Preparing to unpack .../142-libnet-dns-perl_1.22-1_all.deb ...
# Unpacking libnet-dns-perl (1.22-1) ...
# Selecting previously unselected package libnet-domain-tld-perl.
# Preparing to unpack .../143-libnet-domain-tld-perl_1.75-1_all.deb ...
# Unpacking libnet-domain-tld-perl (1.75-1) ...
# Selecting previously unselected package libemail-valid-perl.
# Preparing to unpack .../144-libemail-valid-perl_1.202-1_all.deb ...
# Unpacking libemail-valid-perl (1.202-1) ...
# Selecting previously unselected package libfont-afm-perl.
# Preparing to unpack .../145-libfont-afm-perl_1.20-2_all.deb ...
# Unpacking libfont-afm-perl (1.20-2) ...
# Selecting previously unselected package libhtml-form-perl.
# Preparing to unpack .../146-libhtml-form-perl_6.07-1_all.deb ...
# Unpacking libhtml-form-perl (6.07-1) ...
# Selecting previously unselected package libhtml-format-perl.
# Preparing to unpack .../147-libhtml-format-perl_2.12-1_all.deb ...
# Unpacking libhtml-format-perl (2.12-1) ...
# Selecting previously unselected package libhttp-daemon-perl.
# Preparing to unpack .../148-libhttp-daemon-perl_6.06-1ubuntu0.1_all.deb ...
# Unpacking libhttp-daemon-perl (6.06-1ubuntu0.1) ...
# Selecting previously unselected package libtypes-serialiser-perl.
# Preparing to unpack .../149-libtypes-serialiser-perl_1.0-1_all.deb ...
# Unpacking libtypes-serialiser-perl (1.0-1) ...
# Selecting previously unselected package libjson-xs-perl.
# Preparing to unpack .../150-libjson-xs-perl_4.020-1build1_amd64.deb ...
# Unpacking libjson-xs-perl (4.020-1build1) ...
# Selecting previously unselected package libnet-dns-sec-perl.
# Preparing to unpack .../151-libnet-dns-sec-perl_1.15-1_amd64.deb ...
# Unpacking libnet-dns-sec-perl (1.15-1) ...
# Selecting previously unselected package libnet-libidn-perl.
# Preparing to unpack .../152-libnet-libidn-perl_0.12.ds-3build2_amd64.deb ...
# Unpacking libnet-libidn-perl (0.12.ds-3build2) ...
# Selecting previously unselected package libpackage-stash-xs-perl.
# Preparing to unpack .../153-libpackage-stash-xs-perl_0.29-1build1_amd64.deb ...
# Unpacking libpackage-stash-xs-perl (0.29-1build1) ...
# Selecting previously unselected package libperl4-corelibs-perl.
# Preparing to unpack .../154-libperl4-corelibs-perl_0.004-2_all.deb ...
# Unpacking libperl4-corelibs-perl (0.004-2) ...
# Selecting previously unselected package libreadonly-perl.
# Preparing to unpack .../155-libreadonly-perl_2.050-2_all.deb ...
# Unpacking libreadonly-perl (2.050-2) ...
# Selecting previously unselected package libref-util-perl.
# Preparing to unpack .../156-libref-util-perl_0.204-1_all.deb ...
# Unpacking libref-util-perl (0.204-1) ...
# Selecting previously unselected package libref-util-xs-perl.
# Preparing to unpack .../157-libref-util-xs-perl_0.117-1build2_amd64.deb ...
# Unpacking libref-util-xs-perl (0.117-1build2) ...
# Selecting previously unselected package libyaml-libyaml-perl.
# Preparing to unpack .../158-libyaml-libyaml-perl_0.81+repack-1_amd64.deb ...
# Unpacking libyaml-libyaml-perl (0.81+repack-1) ...
# Selecting previously unselected package ssl-cert.
# Preparing to unpack .../159-ssl-cert_1.0.39_all.deb ...
# Unpacking ssl-cert (1.0.39) ...
# Selecting previously unselected package libauthen-sasl-perl.
# Preparing to unpack .../160-libauthen-sasl-perl_2.1600-1_all.deb ...
# Unpacking libauthen-sasl-perl (2.1600-1) ...
# Setting up git-gui (1:2.25.1-1ubuntu3.8) ...
# Setting up libhttp-date-perl (6.05-1) ...
# Setting up libotf0:amd64 (0.9.13-7) ...
# Setting up imagemagick-6-common (8:6.9.10.23+dfsg-2.1ubuntu11.4) ...
# Setting up libfile-listing-perl (6.04-1) ...
# Setting up fonts-noto-mono (20200323-1build1~ubuntu20.04.1) ...
# Setting up libclass-inspector-perl (1.36-1) ...
# Setting up libfont-afm-perl (1.20-2) ...
# Setting up libdynaloader-functions-perl (0.003-1) ...
# Setting up libclass-method-modifiers-perl (2.13-1) ...
# Setting up libref-util-xs-perl (0.117-1build2) ...
# Setting up libsub-identify-perl (0.14-1build2) ...
# Setting up libhtml-tagset-perl (3.20-4) ...
# Setting up cvs (2:1.12.13+real-27build1) ...
# Allowing use of questionable username.
# Adding group `_cvsadmin' (GID 113) ...
# Done.
# Setting up libijs-0.35:amd64 (0.35-15) ...
# Setting up libauthen-sasl-perl (2.1600-1) ...
# Setting up libutf8proc2:amd64 (2.5.0-1) ...
# Setting up libperl4-corelibs-perl (0.004-2) ...
# Setting up liblwp-mediatypes-perl (6.04-1) ...
# Setting up libyaml-libyaml-perl (0.81+repack-1) ...
# Setting up libtry-tiny-perl (0.30-1) ...
# Setting up libapr1:amd64 (1.6.5-1ubuntu1) ...
# Setting up m17n-db (1.8.0-3) ...
# Setting up perl-openssl-defaults:amd64 (4) ...
# Setting up libcommon-sense-perl (3.74-2build6) ...
# Setting up libclass-singleton-perl (1.5-1) ...
# Setting up libpadwalker-perl (2.3-1build2) ...
# Setting up libencode-locale-perl (1.05-1) ...
# Setting up libm17n-0:amd64 (1.8.0-2) ...
# Setting up fonts-urw-base35 (20170801.1-3) ...
# Setting up libxstring-perl (0.002-2) ...
# Setting up git-doc (1:2.25.1-1ubuntu3.8) ...
# Setting up libyaml-perl (1.30-1) ...
# Setting up libclass-c3-xs-perl (0.14-1build5) ...
# Setting up gitk (1:2.25.1-1ubuntu3.8) ...
# Setting up libdevel-caller-perl (2.06-2build2) ...
# Setting up libsub-install-perl (0.928-1) ...
# Setting up poppler-data (0.4.9-2) ...
# Setting up runit (2.1.2-9.2ubuntu1) ...
# Setting up libreadonly-perl (2.050-2) ...
# Setting up libdevel-lexalias-perl (0.05-2build2) ...
# Setting up libpackage-stash-xs-perl (0.29-1build1) ...
# Setting up elpa-treepy (0.1.1-2) ...
# Setting up libclass-data-inheritable-perl (0.08-3) ...
# Setting up libalgorithm-c3-perl (0.10-1) ...
# Setting up libdata-dump-perl (1.23-1) ...
# Setting up libdigest-hmac-perl (1.03+dfsg-2) ...
# Setting up libref-util-perl (0.204-1) ...
# Setting up ssl-cert (1.0.39) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# Setting up libjbig2dec0:amd64 (0.18-1ubuntu1) ...
# Setting up libidn11:amd64 (1.33-2.2ubuntu2) ...
# Setting up libnet-domain-tld-perl (1.75-1) ...
# Setting up dh-elpa-helper (2.0.2) ...
# Setting up gsfonts (1:8.11+urwcyr1.0.7~pre44-4.4) ...
# Setting up libnet-libidn-perl (0.12.ds-3build2) ...
# Setting up libvariable-magic-perl (0.62-1build2) ...
# Setting up libio-html-perl (1.001-1) ...
# Setting up libb-hooks-op-check-perl (0.22-1build2) ...
# Setting up libparams-util-perl (1.07-3build5) ...
# Setting up libsub-exporter-progressive-perl (0.001013-1) ...
# Setting up libsub-name-perl (0.26-1) ...
# Setting up libtypes-serialiser-perl (1.0-1) ...
# Setting up elpa-let-alist (1.0.6-1) ...
# Setting up liblua5.2-0:amd64 (5.2.4-1.1build3) ...
# Setting up liblqr-1-0:amd64 (0.4.2-2.1) ...
# Setting up git-email (1:2.25.1-1ubuntu3.8) ...
# Setting up libjson-perl (4.02000-2) ...
# Setting up librole-tiny-perl (2.001004-1) ...
# Setting up libfile-sharedir-perl (1.116-2) ...
# Setting up libfcgi-perl (0.79-1) ...
# Setting up netbase (6.1) ...
# Setting up libsub-quote-perl (2.006006-1) ...
# Setting up libdevel-stacktrace-perl (2.0400-1) ...
# Setting up libclass-xsaccessor-perl (1.19-3build3) ...
# Setting up apache2-data (2.4.41-4ubuntu3.13) ...
# Setting up fonts-droid-fallback (1:6.0.1r16-1.1) ...
# Setting up cvsps (2.1-8build2) ...
# Setting up libterm-readkey-perl (2.38-1build1) ...
# Setting up emacs-common (1:26.3+1-1ubuntu2) ...
# Setting up libnet-ip-perl (1.26-2) ...
# Setting up liburi-perl (1.76-2) ...
# Setting up libdbi-perl:amd64 (1.643-1ubuntu0.1) ...
# Setting up libhttp-message-perl (6.22-1) ...
# Setting up libaprutil1:amd64 (1.6.1-4ubuntu2) ...
# Setting up libdigest-bubblebabble-perl (0.02-2) ...
# Setting up elpa-ghub (3.3.0-1) ...
# Setting up libnet-ssleay-perl (1.88-2ubuntu1) ...
# Setting up libgs9-common (9.50~dfsg-5ubuntu4.6) ...
# Setting up libjson-xs-perl (4.020-1build1) ...
# Setting up libhttp-negotiate-perl (6.01-1) ...
# Setting up libgs9:amd64 (9.50~dfsg-5ubuntu4.6) ...
# Setting up git-daemon-run (1:2.25.1-1ubuntu3.8) ...
# Warning: The home dir /nonexistent you specified can't be accessed: No such file or directory
# Adding system user `gitlog' (UID 107) ...
# Adding new user `gitlog' (UID 107) with group `nogroup' ...
# Not creating home directory `/nonexistent'.
# Warning: The home dir /nonexistent you specified can't be accessed: No such file or directory
# Adding system user `gitdaemon' (UID 108) ...
# Adding new user `gitdaemon' (UID 108) with group `nogroup' ...
# Not creating home directory `/nonexistent'.
# Service git-daemon added.
# Setting up libhttp-cookies-perl (6.08-1) ...
# Setting up libserf-1-1:amd64 (1.3.9-8build1) ...
# Setting up libnet-http-perl (6.19-1) ...
# Setting up libnet-dns-perl (1.22-1) ...
# Setting up libexception-class-perl (1.44-1) ...
# Setting up libaprutil1-ldap:amd64 (1.6.1-4ubuntu2) ...
# Setting up libclass-c3-perl (0.34-1) ...
# Setting up elpa-with-editor (2.9.1-1) ...
# Setting up ghostscript (9.50~dfsg-5ubuntu4.6) ...
# Setting up libaprutil1-dbd-sqlite3:amd64 (1.6.1-4ubuntu2) ...
# Setting up libdevel-callchecker-perl (0.008-1ubuntu1) ...
# Setting up libmagickcore-6.q16-6:amd64 (8:6.9.10.23+dfsg-2.1ubuntu11.4) ...
# Setting up elpa-dash (2.17.0+dfsg-1) ...
# Setting up libdata-optlist-perl (0.110-1) ...
# Setting up emacs-el (1:26.3+1-1ubuntu2) ...
# Setting up libwww-robotrules-perl (6.02-1) ...
# Setting up libhttp-daemon-perl (6.06-1ubuntu0.1) ...
# Setting up libhtml-parser-perl (3.72-5) ...
# Setting up emacs-bin-common (1:26.3+1-1ubuntu2) ...
# update-alternatives: using /usr/bin/ctags.emacs to provide /usr/bin/ctags (ctags) in auto mode
# update-alternatives: using /usr/bin/ebrowse.emacs to provide /usr/bin/ebrowse (ebrowse) in auto mode
# update-alternatives: using /usr/bin/emacsclient.emacs to provide /usr/bin/emacsclient (emacsclient) in auto mode
# update-alternatives: using /usr/bin/etags.emacs to provide /usr/bin/etags (etags) in auto mode
# Setting up libmagickwand-6.q16-6:amd64 (8:6.9.10.23+dfsg-2.1ubuntu11.4) ...
# Setting up libdbd-sqlite3-perl:amd64 (1.64-1build1) ...
# Setting up libmro-compat-perl (0.13-1) ...
# Setting up libsvn1:amd64 (1.13.0-3ubuntu0.2) ...
# Setting up elpa-git-commit (2.90.1-2) ...
# tsort: -: input contains a loop:
# tsort: elpa-dash
# tsort: emacsen-common
# tsort: -: input contains a loop:
# tsort: emacsen-common
# tsort: elpa-with-editor
# Setting up libio-socket-ssl-perl (2.067-1) ...
# Setting up libsub-exporter-perl (0.987-1) ...
# Setting up apache2-utils (2.4.41-4ubuntu3.13) ...
# Setting up libeval-closure-perl (0.14-1) ...
# Setting up libhtml-form-perl (6.07-1) ...
# Setting up libparams-validationcompiler-perl (0.30-1) ...
# Setting up libsvn-perl:amd64 (1.13.0-3ubuntu0.2) ...
# Setting up git-cvs (1:2.25.1-1ubuntu3.8) ...
# Setting up libhtml-tree-perl (5.07-2) ...
# Setting up libparams-classify-perl (0.015-1build2) ...
# Setting up libcgi-pm-perl (4.46-1) ...
# Setting up elpa-magit-popup (2.13.2-1) ...
# tsort: -: input contains a loop:
# tsort: elpa-dash
# tsort: emacsen-common
# Setting up libnet-dns-sec-perl (1.15-1) ...
# Setting up elpa-magit (2.90.1-2) ...
# tsort: -: input contains a loop:
# tsort: elpa-dash
# tsort: emacsen-common
# tsort: -: input contains a loop:
# tsort: elpa-ghub
# tsort: emacsen-common
# tsort: -: input contains a loop:
# tsort: elpa-git-commit
# tsort: emacsen-common
# tsort: elpa-with-editor
# tsort: -: input contains a loop:
# tsort: elpa-git-commit
# tsort: emacsen-common
# tsort: -: input contains a loop:
# tsort: emacsen-common
# tsort: elpa-magit-popup
# tsort: -: input contains a loop:
# tsort: elpa-with-editor
# tsort: emacsen-common
# Install git for emacs
# Setting up libhtml-format-perl (2.12-1) ...
# Setting up git-svn (1:2.25.1-1ubuntu3.8) ...
# Setting up apache2-bin (2.4.41-4ubuntu3.13) ...
# Setting up libnet-smtp-ssl-perl (1.04-1) ...
# Setting up libmodule-runtime-perl (0.016-1) ...
# Setting up libmailtools-perl (2.21-1) ...
# Setting up emacs-gtk (1:26.3+1-1ubuntu2) ...
# update-alternatives: using /usr/bin/emacs-gtk to provide /usr/bin/emacs (emacs) in auto mode
# Install emacsen-common for emacs
# emacsen-common: Handling install of emacsen flavor emacs
# Install git for emacs
# Install elpa-with-editor for emacs
# install/with-editor-2.6.0: Handling install of emacsen flavor emacs
# install/with-editor-2.6.0: byte-compiling for emacs
# Install dictionaries-common for emacs
# install/dictionaries-common: Byte-compiling for emacsen flavour emacs
# Install cmake-data for emacs
# Install elpa-treepy for emacs
# install/treepy-0.1.1: Handling install of emacsen flavor emacs
# install/treepy-0.1.1: byte-compiling for emacs
# Install elpa-dash for emacs
# install/dash-2.17.0: Handling install of emacsen flavor emacs
# install/dash-2.17.0: byte-compiling for emacs
# Install elpa-let-alist for emacs
# install/let-alist-1.0.6: Handling install of emacsen flavor emacs
# install/let-alist-1.0.6: byte-compiling for emacs
# Install elpa-git-commit for emacs
# install/git-commit-2.90.1: Handling install of emacsen flavor emacs
# install/git-commit-2.90.1: byte-compiling for emacs
# Install elpa-magit-popup for emacs
# install/magit-popup-2.13.2: Handling install of emacsen flavor emacs
# install/magit-popup-2.13.2: byte-compiling for emacs
# Install elpa-ghub for emacs
# install/ghub-3.3.0: Handling install of emacsen flavor emacs
# install/ghub-3.3.0: byte-compiling for emacs
# Install elpa-magit for emacs
# install/magit-2.90.1: Handling install of emacsen flavor emacs
# install/magit-2.90.1: byte-compiling for emacs
# Setting up gitweb (1:2.25.1-1ubuntu3.8) ...
# Package apache2 is not configured yet. Will defer actions by package gitweb.
# Setting up git-el (1:2.25.1-1ubuntu3.8) ...
# Install git for emacs
# Install git for emacs
# Setting up emacs (1:26.3+1-1ubuntu2) ...
# Setting up libmodule-implementation-perl (0.09-1) ...
# Setting up libemail-valid-perl (1.202-1) ...
# Setting up libcgi-fast-perl (1:2.15-1) ...
# Setting up libpackage-stash-perl (0.38-1) ...
# Setting up apache2 (2.4.41-4ubuntu3.13) ...
# Enabling module mpm_event.
# Enabling module authz_core.
# Enabling module authz_host.
# Enabling module authn_core.
# Enabling module auth_basic.
# Enabling module access_compat.
# Enabling module authn_file.
# Enabling module authz_user.
# Enabling module alias.
# Enabling module dir.
# Enabling module autoindex.
# Enabling module env.
# Enabling module mime.
# Enabling module negotiation.
# Enabling module setenvif.
# Enabling module filter.
# Enabling module deflate.
# Enabling module status.
# Enabling module reqtimeout.
# Enabling conf charset.
# Enabling conf localized-error-pages.
# Enabling conf other-vhosts-access-log.
# Enabling conf security.
# Enabling conf serve-cgi-bin.
# Enabling site 000-default.
# info: Executing deferred 'a2enconf gitweb' for package gitweb
# Enabling conf gitweb.
# Created symlink /etc/systemd/system/multi-user.target.wants/apache2.service → /lib/systemd/system/apache2.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/apache-htcacheclean.service → /lib/systemd/system/apache-htcacheclean.service.
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up libspecio-perl (0.45-1) ...
# Setting up libparams-validate-perl (1.29-3) ...
# Setting up libb-hooks-endofscope-perl (0.24-1) ...
# Setting up libnamespace-clean-perl (0.27-1) ...
# Setting up libnamespace-autoclean-perl (0.29-1) ...
# Setting up libdatetime-locale-perl (1:1.25-1) ...
# Setting up libdatetime-timezone-perl (1:2.38-1+2019c) ...
# Setting up libdatetime-perl:amd64 (2:1.51-1build1) ...
# Setting up libdatetime-format-strptime-perl (1.7600-1) ...
# Setting up libdatetime-format-builder-perl (0.8200-1) ...
# Setting up libdatetime-format-iso8601-perl (0.08-2) ...
# Setting up liblwp-protocol-https-perl (6.07-2ubuntu2) ...
# Setting up libwww-perl (6.43-1) ...
# Setting up libmediawiki-api-perl (0.41-2) ...
# Setting up git-mediawiki (1:2.25.1-1ubuntu3.8) ...
# Setting up git-all (1:2.25.1-1ubuntu3.8) ...
# Processing triggers for install-info (6.7.0.dfsg.2-5) ...
# Processing triggers for fontconfig (2.13.1-2ubuntu3) ...
# Processing triggers for mime-support (3.64ubuntu1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Processing triggers for systemd (245.4-4ubuntu3.19) ...
# Processing triggers for man-db (2.9.1-1) ...

# %%
tutorial/master/se!wget https://raw.githubusercontent.com/AssemblyAI/kaldi-asr-tup.sh
# Out:
# --2023-02-13 19:42:49--  https://raw.githubusercontent.com/AssemblyAI/kaldi-asr-tutorial/master/setup.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1306 (1.3K) [text/plain]
# Saving to: ‘setup.sh’
#
# setup.sh            100%[===================>]   1.28K  --.-KB/s    in 0s
#
# 2023-02-13 19:42:49 (82.9 MB/s) - ‘setup.sh’ saved [1306/1306]
